# %%
# 분할된 파일의 데이터를 합친다
files = ['./crwaling/save_arittaum_1to7.txt','./crwaling/save_arittaum_8to20.txt']

datas = []

for file in files:
    with open(file, 'r', encoding='utf-8') as contents:
        for content in contents:
            datas.append(content)
# Out:
# [색조] Eye@@@아리따움 아이돌 마스크라 롱래쉬 사용후기에요!@@@2017.10.13. 18:37@@@나엉2(yny1****)@@@안녕하세요속눈썹연장을 항상하고있는 처자랍니다속눈썹연장을 잠깐 쉬고 있을때 구매한 마스카라를 소개해드릴게요       아이돌 롱래쉬 마스카라 블랙이에요    롱래쉬랑 컬링업 두가지였는데 저는 긴 속눈썹을 좋아해서 롱래쉬로!   속눈썹연장 한듯이 길게 연출해준다길래 바로구매!    많이 뭉치지않아서 좋아요리무버 없이 물로도 마스카라 제거가 되서 굉장히 편해요     부끄럽지만 마스카라 한 제 눈이에요ㅎㅎㅎㅎㅎㅎ굉장히 길어보이죠?여러번 덧바르니까 더 길어보여서 굳굳@@@http://cafe.naver.com/mp3musicdownloadcafe@@@1

# %%
# 합쳐진 데이터를 저장한다

save_path = './crwaling/save_arittaum_1to20.txt'

with open(save_path, 'w',encoding='utf-8') as save:
    for data in datas:
        save.writelines(data)

# %%
# string 형식의 데이터를 분할한다. 

# results.append("{}@@@{}@@@{}@@@{}@@@{}@@@{}@@@{}\n".format(board, title, date, writer, content, naver_cafe, page))

datas_raw = datas
datas=[]

for data_raw in datas_raw:
    split = data_raw.split('@@@')
    datas.append(split)
print(datas[0])    # 마지막 데이터에서 \n 은 제거했어야 했음.....
print(len(datas[0]))
# Out:
# ['[색조] Eye', '아리따움 아이돌 마스크라 롱래쉬 사용후기에요!', '2017.10.13. 18:37', '나엉2(yny1****)', '안녕하세요속눈썹연장을 항상하고있는 처자랍니다속눈썹연장을 잠깐 쉬고 있을때 구매한 마스카라를 소개해드릴게요       아이돌 롱래쉬 마스카라 블랙이에요    롱래쉬랑 컬링업 두가지였는데 저는 긴 속눈썹을 좋아해서 롱래쉬로!   속눈썹연장 한듯이 길게 연출해준다길래 바로구매!    많이 뭉치지않아서 좋아요리무버 없이 물로도 마스카라 제거가 되서 굉장히 편해요     부끄럽지만 마스카라 한 제 눈이에요ㅎㅎㅎㅎㅎㅎ굉장히 길어보이죠?여러번 덧바르니까 더 길어보여서 굳굳', 'http://cafe.naver.com/mp3musicdownloadcafe', '1\n']
# 7

# %%
from konlpy.tag import Komoran
from konlpy.tag import Twitter

# %%
contents = []
for data in datas:
    contents.append(data[4])
print(contents[3])
# Out:
# 안녕하세요! 요즘 핫한 쿠션이죠? '마몽드 브라이트닝 커버파우더 쿠션'을소개해드리고자 해요!브라이트닝 쿠션라인은 파우더/ 워터리/ 새로나온 앰플까지 세 종류의라인으로 구성되어 있는데요! 각각 지성, 건성, 신상품인 겨울용 앰플쿠션까지!열일하는 마몽드..! 유형별로 자상하게 출시를..ㅎㅎㅎ 저 위생필름을 뗄 때가 가장 좋아요.ㅎㅎ 저는 옐로 베이스, 21N호 미디엄 베이지를 선택!예전에는 무조건 하얗게!! 만 하는 화장이 예뻐보였는데나이가 들어갈수록...ㅋㅋㅋ 피부는 역시 자연스러운  화장이 좋은 것 같아요! 마몽드 쿠션은각자 피부톤에 맞는 베이스선택과 더불어밝기조절의 선택폭까지 매우 넓답니다!복숭아꽃 쿠션이라는 수식어가 붙은 이유는바로 복숭아 꽃잎의 미세돌기를 묘사한 파우더 쿠션이기 때문인데요!덕분에 밀착력이 높아져 높은 커버력을 자랑한답니다.복숭아 솜털처럼 뽀송뽀송한 피부연출... 복숭아를 만졌을 때 그 뽀송뽀송한촉감을 연출하기위해 퍼프에 신경을 쓴 흔적이..!이래서 두드릴 때마다 화장이 두꺼워지는 느낌없이더 촘촘히 밀착되었나봐요!퍼프마저 완벽한 브라이트닝 파우더쿠션!C가 붙은게 핑크베이스, N이 붙은게 옐로우 베이스에요.저는 가운데 있는 미디엄 베이지!ㅎㅎ 와. 정말 고르게 묻어나오지 않나요?바르기 전부터 뽀송뽀송한 느낌 뿜뿜..... 먼저 손등테스트! 브라운컬러의 아이라이너 위에쿠션을 살짝 두드려 봤는데요!정말 커버가 확실히 좋은게 느껴져요! Before, After!  원래는 피부가 예민해져있어서 살짝 홍조끼가 보였었는데, 옐로우 베이스의파우더쿠션을 바르니까 톤을 확실히잡아주는 느낌! 우측 상단의눈밑 다크서클 보이시나요..?ㅋㅋㅋ다크서클까지 바로커버.........복숭아 표면을 닮은 퍼프 덕분인지, 두드릴 수록자연스러워지는 커버력. 절대로 여러번두드린다고 해서 화장이 두꺼워지지 않았어요!거기다 이정도 커버력이면별도로 컨실러를 사용하지않아도 될 것같아요!강남역 아리따움에 있는 마몽드에요!디스플레이에 홀려서 또 하나 장만할뻔한..ㅋㅋㅋㅋㅋㅋ 마몽드 브라이트닝 쿠션은 제가 사용한 파우더타입 / 워터리 타입으로 되어있는데요!파우더타입은 요즘  벨벳텍스츄어의 립들이유행하잖아요!? 그것처럼 속은 그렇게 건조하지 않은데겉은 정말 뽀송하게 마무리되어서 좋았어요.정말 지성인 분들에게 강력추천...두번추천......거기다 컨실러 사용도 필요없을만큼 커버력이좋아서, 컨실러+쿠션+파우더가 하나로합쳐져진 느낌..... 인생쿠션...앞으로 쿠션은 너로정했다....!그리고 마몽드 홈페이지를 보니까,이제 곧 겨울이잖아요? 시즌에 맞춰서앰플쿠션도 새로 출시되었더라구요!겨울 건조한 피부를 보호하기 위한앰플쿠션! 테스터 해보러매장방문해야겠어요! ㅎㅎㅎ

# %%
# 형태소 분석하기

def ma_contents(contents):
    # lists 로 된 데이터 입력 --> 형태소 분석 결과 출력
    
    ma_results = []
    ma = Twitter()
    
    for content in contents:
        ma_by_content = ma.pos(content)
        ma_results.append(ma_by_content)
    
    return ma_results

# %%
#test 용
ma_results = ma_contents(contents)
ma_results[3]
# Out:
# [('안녕하세', 'Adjective'),
#  ('요', 'Eomi'),
#  ('!', 'Punctuation'),
#  ('요즘', 'Noun'),
#  ('핫', 'Noun'),
#  ('한', 'Josa'),
#  ('쿠션', 'Noun'),
#  ('이', 'Suffix'),
#  ('죠', 'Josa'),
#  ('?', 'Punctuation'),
#  ("'", 'Punctuation'),
#  ('마몽드', 'Noun'),
#  ('브', 'Noun'),
#  ('라이트닝', 'Noun'),
#  ('커버', 'Noun'),
#  ('파우더', 'Noun'),
#  ('쿠션', 'Noun'),
#  ("'", 'Punctuation'),
#  ('을소', 'Noun'),
#  ('개', 'Suffix'),
#  ('해드리', 'Verb'),
#  ('고자', 'Eomi'),
#  ('해', 'Noun'),
#  ('요', 'Josa'),
#  ('!', 'Punctuation'),
#  ('브', 'Noun'),
#  ('라이트닝', 'Noun'),
#  ('쿠션', 'Noun'),
#  ('라인', 'Noun'),
#  ('은', 'Josa'),
#  ('파우더', 'Noun'),
#  ('/', 'Punctuation'),
#  ('워터', 'Noun'),
#  ('리', 'Noun'),
#  ('/', 'Punctuation'),
#  ('새로', 'Adjective'),
#  ('나온', 'Verb'),
#  ('앰플', 'Noun'),
#  ('까지', 'Josa'),
#  ('세', 'Noun'),
#  ('종류', 'Noun'),
#  ('의', 'Josa'),
#  ('라인', 'Noun'),
#  ('으로', 'Josa'),
#  ('구성되', 'Verb'),
#  ('어', 'Eomi'),
#  ('있는', 'Adjective'),
#  ('데요', 'Eomi'),
#  ('!', 'Punctuation'),
#  ('각각', 'Noun'),
#  ('지성', 'Noun'),
#  (',', 'Punctuation'),
#  ('건성', 'Noun'),
#  (',', 'Punctuation'),
#  ('신', 'Noun'),
#  ('상품', 'Noun'),
#  ('인', 'Josa'),
#  ('겨울', 'Noun'),
#  ('용', 'Noun'),
#  ('앰플쿠션', 'Noun'),
#  ('까지', 'Josa'),
#  ('!', 'Punctuation'),
#  ('열', 'Noun'),
#  ('일하는', 'Verb'),
#  ('마몽드', 'Noun'),
#  ('..!', 'Punctuation'),
#  ('유형', 'Noun'),
#  ('별로', 'Noun'),
#  ('자상', 'Noun'),
#  ('하게', 'Verb'),
#  ('출시', 'Noun'),
#  ('를', 'Josa'),
#  ('..', 'Punctuation'),
#  ('ㅎㅎㅎ', 'KoreanParticle'),
#  ('저', 'Noun'),
#  ('위생', 'Noun'),
#  ('필름', 'Noun'),
#  ('을', 'Josa'),
#  ('뗄', 'Verb'),
#  ('때', 'Noun'),
#  ('가', 'Josa'),
#  ('가장', 'Noun'),
#  ('좋', 'Adjective'),
#  ('아요', 'Eomi'),
#  ('.', 'Punctuation'),
#  ('ㅎㅎ', 'KoreanParticle'),
#  ('저', 'Noun'),
#  ('는', 'Josa'),
#  ('옐로', 'Noun'),
#  ('베이스', 'Noun'),
#  (',', 'Punctuation'),
#  ('21', 'Number'),
#  ('N', 'Alpha'),
#  ('호', 'Noun'),
#  ('미디엄', 'Noun'),
#  ('베이지', 'Noun'),
#  ('를', 'Josa'),
#  ('선택', 'Noun'),
#  ('!', 'Punctuation'),
#  ('예전', 'Noun'),
#  ('에는', 'Josa'),
#  ('무조건', 'Noun'),
#  ('하얗', 'Adjective'),
#  ('게', 'Eomi'),
#  ('!!', 'Punctuation'),
#  ('만', 'Noun'),
#  ('하는', 'Verb'),
#  ('화장', 'Noun'),
#  ('이', 'Josa'),
#  ('예뻐', 'Adjective'),
#  ('보였', 'Verb'),
#  ('는데', 'Eomi'),
#  ('나이', 'Noun'),
#  ('가', 'Josa'),
#  ('들어갈', 'Verb'),
#  ('수', 'PreEomi'),
#  ('록', 'Eomi'),
#  ('...', 'Punctuation'),
#  ('ㅋㅋㅋ', 'KoreanParticle'),
#  ('피부', 'Noun'),
#  ('는', 'Josa'),
#  ('역시', 'Noun'),
#  ('자연스러운', 'Adjective'),
#  ('화장', 'Noun'),
#  ('이', 'Josa'),
#  ('좋', 'Adjective'),
#  ('은', 'Eomi'),
#  ('것', 'Noun'),
#  ('같아', 'Adjective'),
#  ('요', 'Eomi'),
#  ('!', 'Punctuation'),
#  ('마몽드', 'Noun'),
#  ('쿠션', 'Noun'),
#  ('은', 'Josa'),
#  ('각자', 'Noun'),
#  ('피부', 'Noun'),
#  ('톤', 'Noun'),
#  ('에', 'Josa'),
#  ('맞는', 'Verb'),
#  ('베이스', 'Noun'),
#  ('선택', 'Noun'),
#  ('과', 'Josa'),
#  ('더불어', 'Verb'),
#  ('밝기', 'Noun'),
#  ('조절', 'Noun'),
#  ('의', 'Josa'),
#  ('선택', 'Noun'),
#  ('폭', 'Noun'),
#  ('까지', 'Josa'),
#  ('매우', 'Noun'),
#  ('넓', 'Adjective'),
#  ('답', 'PreEomi'),
#  ('니다', 'Eomi'),
#  ('!', 'Punctuation'),
#  ('복숭아꽃', 'Noun'),
#  ('쿠션', 'Noun'),
#  ('이라는', 'Josa'),
#  ('수식어', 'Noun'),
#  ('가', 'Josa'),
#  ('붙은', 'Verb'),
#  ('이유', 'Noun'),
#  ('는바', 'Noun'),
#  ('로', 'Josa'),
#  ('복숭아', 'Noun'),
#  ('꽃잎', 'Noun'),
#  ('의', 'Josa'),
#  ('미세', 'Noun'),
#  ('돌기', 'Noun'),
#  ('를', 'Josa'),
#  ('묘사한', 'Verb'),
#  ('파우더', 'Noun'),
#  ('쿠션', 'Noun'),
#  ('이기', 'Noun'),
#  ('때문', 'Noun'),
#  ('인데', 'Josa'),
#  ('요', 'Noun'),
#  ('!', 'Punctuation'),
#  ('덕분', 'Noun'),
#  ('에', 'Josa'),
#  ('밀착', 'Noun'),
#  ('력', 'Suffix'),
#  ('이', 'Josa'),
#  ('높아져', 'Verb'),
#  ('높은', 'Adjective'),
#  ('커버', 'Noun'),
#  ('력', 'Suffix'),
#  ('을', 'Josa'),
#  ('자랑한', 'Verb'),
#  ('답', 'PreEomi'),
#  ('니다', 'Eomi'),
#  ('.', 'Punctuation'),
#  ('복숭아', 'Noun'),
#  ('솜털', 'Noun'),
#  ('처럼', 'Josa'),
#  ('뽀송뽀송', 'Adverb'),
#  ('한', 'Determiner'),
#  ('피부', 'Noun'),
#  ('연출', 'Noun'),
#  ('...', 'Punctuation'),
#  ('복숭아', 'Noun'),
#  ('를', 'Josa'),
#  ('만졌', 'Verb'),
#  ('을', 'Eomi'),
#  ('때', 'Noun'),
#  ('그', 'Noun'),
#  ('뽀송뽀송', 'Adverb'),
#  ('한', 'Determiner'),
#  ('촉감', 'Noun'),
#  ('을', 'Josa'),
#  ('연출하기', 'Verb'),
#  ('위해', 'Noun'),
#  ('퍼프', 'Noun'),
#  ('에', 'Josa'),
#  ('신경', 'Noun'),
#  ('을', 'Josa'),
#  ('쓴', 'Verb'),
#  ('흔적', 'Noun'),
#  ('이', 'Josa'),
#  ('..!', 'Punctuation'),
#  ('이래서', 'Josa'),
#  ('두드릴', 'Verb'),
#  ('때', 'Noun'),
#  ('마다', 'Josa'),
#  ('화장', 'Noun'),
#  ('이', 'Josa'),
#  ('두꺼워', 'Adjective'),
#  ('지는', 'Eomi'),
#  ('느낌', 'Noun'),
#  ('없이', 'Adverb'),
#  ('더', 'Noun'),
#  ('촘촘히', 'Adverb'),
#  ('밀착', 'Noun'),
#  ('되었', 'Verb'),
#  ('나', 'Eomi'),
#  ('봐', 'Noun'),
#  ('요', 'Josa'),
#  ('!', 'Punctuation'),
#  ('퍼프', 'Noun'),
#  ('마저', 'Josa'),
#  ('완벽한', 'Adjective'),
#  ('브', 'Noun'),
#  ('라이트닝', 'Noun'),
#  ('파우더', 'Noun'),
#  ('쿠션', 'Noun'),
#  ('!', 'Punctuation'),
#  ('C', 'Alpha'),
#  ('가', 'Verb'),
#  ('붙은', 'Verb'),
#  ('게', 'Eomi'),
#  ('핑크', 'Noun'),
#  ('베이스', 'Noun'),
#  (',', 'Punctuation'),
#  ('N', 'Alpha'),
#  ('이', 'Noun'),
#  ('붙은', 'Verb'),
#  ('게', 'Eomi'),
#  ('옐로우', 'Noun'),
#  ('베이스', 'Noun'),
#  ('에요', 'Josa'),
#  ('.', 'Punctuation'),
#  ('저', 'Noun'),
#  ('는', 'Josa'),
#  ('가운데', 'Noun'),
#  ('있는', 'Adjective'),
#  ('미디엄', 'Noun'),
#  ('베이지', 'Noun'),
#  ('!', 'Punctuation'),
#  ('ㅎㅎ', 'KoreanParticle'),
#  ('와', 'Noun'),
#  ('.', 'Punctuation'),
#  ('정말', 'Noun'),
#  ('고르', 'Verb'),
#  ('게', 'Eomi'),
#  ('묻', 'Verb'),
#  ('어', 'Eomi'),
#  ('나오지', 'Verb'),
#  ('않', 'Verb'),
#  ('나요', 'Eomi'),
#  ('?', 'Punctuation'),
#  ('바르', 'Verb'),
#  ('기', 'Eomi'),
#  ('전', 'Noun'),
#  ('부터', 'Josa'),
#  ('뽀송뽀송', 'Adverb'),
#  ('한', 'Determiner'),
#  ('느낌', 'Noun'),
#  ('뿜뿜', 'Noun'),
#  ('.....', 'Punctuation'),
#  ('먼저', 'Noun'),
#  ('손등', 'Noun'),
#  ('테스트', 'Noun'),
#  ('!', 'Punctuation'),
#  ('브라운', 'Noun'),
#  ('컬러', 'Noun'),
#  ('의', 'Josa'),
#  ('아이라이너', 'Noun'),
#  ('위', 'Noun'),
#  ('에', 'Josa'),
#  ('쿠션', 'Noun'),
#  ('을', 'Josa'),
#  ('살짝', 'Noun'),
#  ('두드려', 'Verb'),
#  ('봤', 'Verb'),
#  ('는', 'PreEomi'),
#  ('데요', 'Eomi'),
#  ('!', 'Punctuation'),
#  ('정말', 'Noun'),
#  ('커버', 'Noun'),
#  ('가', 'Josa'),
#  ('확실히', 'Adjective'),
#  ('좋', 'Adjective'),
#  ('은', 'Noun'),
#  ('게', 'Josa'),
#  ('느껴져', 'Verb'),
#  ('요', 'Eomi'),
#  ('!', 'Punctuation'),
#  ('Before', 'Alpha'),
#  (',', 'Punctuation'),
#  ('After', 'Alpha'),
#  ('!', 'Punctuation'),
#  ('원래', 'Noun'),
#  ('는', 'Josa'),
#  ('피부', 'Noun'),
#  ('가', 'Josa'),
#  ('예민', 'Noun'),
#  ('해', 'Josa'),
#  ('져', 'Verb'),
#  ('있', 'PreEomi'),
#  ('어서', 'Eomi'),
#  ('살짝', 'Noun'),
#  ('홍', 'Noun'),
#  ('조끼', 'Noun'),
#  ('가', 'Josa'),
#  ('보였', 'Verb'),
#  ('었', 'PreEomi'),
#  ('는데', 'Eomi'),
#  (',', 'Punctuation'),
#  ('옐로우', 'Noun'),
#  ('베이스', 'Noun'),
#  ('의', 'Josa'),
#  ('파우더', 'Noun'),
#  ('쿠션', 'Noun'),
#  ('을', 'Josa'),
#  ('바르니', 'Verb'),
#  ('까', 'Eomi'),
#  ('톤', 'Noun'),
#  ('을', 'Josa'),
#  ('확실히', 'Adjective'),
#  ('잡아', 'Verb'),
#  ('주', 'PreEomi'),
#  ('는', 'Eomi'),
#  ('느낌', 'Noun'),
#  ('!', 'Punctuation'),
#  ('우측', 'Noun'),
#  ('상단', 'Noun'),
#  ('의', 'Josa'),
#  ('눈밑', 'Noun'),
#  ('다크서클', 'Noun'),
#  ('보이', 'Verb'),
#  ('시', 'PreEomi'),
#  ('나요', 'Eomi'),
#  ('..?', 'Punctuation'),
#  ('ㅋㅋㅋ', 'KoreanParticle'),
#  ('다크서클', 'Noun'),
#  ('까지', 'Josa'),
#  ('바로', 'Noun'),
#  ('커버', 'Noun'),
#  ('.........', 'Punctuation'),
#  ('복숭아', 'Noun'),
#  ('표면', 'Noun'),
#  ('을', 'Josa'),
#  ('닮은', 'Verb'),
#  ('퍼프', 'Noun'),
#  ('덕분', 'Noun'),
#  ('인지', 'Josa'),
#  (',', 'Punctuation'),
#  ('두드릴', 'Verb'),
#  ('수록', 'Noun'),
#  ('자연스러워', 'Adjective'),
#  ('지는', 'Eomi'),
#  ('커버', 'Noun'),
#  ('력', 'Suffix'),
#  ('.', 'Punctuation'),
#  ('절대로', 'Noun'),
#  ('여러', 'Noun'),
#  ('번', 'Noun'),
#  ('두드린', 'Verb'),
#  ('다고', 'Eomi'),
#  ('해서', 'Verb'),
#  ('화장', 'Noun'),
#  ('이', 'Josa'),
#  ('두꺼워', 'Adjective'),
#  ('지', 'PreEomi'),
#  ('지', 'Eomi'),
#  ('않았', 'Verb'),
#  ('어요', 'Eomi'),
#  ('!', 'Punctuation'),
#  ('거기', 'Noun'),
#  ('다', 'Josa'),
#  ('이정', 'Noun'),
#  ('도', 'Josa'),
#  ('커버', 'Noun'),
#  ('력', 'Suffix'),
#  ('이면', 'Noun'),
#  ('별도', 'Noun'),
#  ('로', 'Josa'),
#  ('컨실러', 'Noun'),
#  ('를', 'Josa'),
#  ('사용하지', 'Verb'),
#  ('않아', 'Verb'),
#  ('도', 'Eomi'),
#  ('될', 'Verb'),
#  ('것', 'Noun'),
#  ('같아', 'Adjective'),
#  ('요', 'Eomi'),
#  ('!', 'Punctuation'),
#  ('강남역', 'Noun'),
#  ('아리따움', 'Noun'),
#  ('에', 'Josa'),
#  ('있는', 'Adjective'),
#  ('마몽드', 'Noun'),
#  ('에요', 'Josa'),
#  ('!', 'Punctuation'),
#  ('디스플레이', 'Noun'),
#  ('에', 'Josa'),
#  ('홀려', 'Noun'),
#  ('서', 'Josa'),
#  ('또', 'Noun'),
#  ('하나', 'Noun'),
#  ('장만', 'Noun'),
#  ('할', 'Verb'),
#  ('뻔한', 'Adjective'),
#  ('..', 'Punctuation'),
#  ('ㅋㅋㅋㅋㅋㅋ', 'KoreanParticle'),
#  ('마몽드', 'Noun'),
#  ('브', 'Noun'),
#  ('라이트닝', 'Noun'),
#  ('쿠션', 'Noun'),
#  ('은', 'Josa'),
#  ('제', 'Noun'),
#  ('가', 'Josa'),
#  ('사용한', 'Verb'),
#  ('파우더', 'Noun'),
#  ('타입', 'Noun'),
#  ('/', 'Punctuation'),
#  ('워터', 'Noun'),
#  ('리', 'Noun'),
#  ('타입', 'Noun'),
#  ('으로', 'Josa'),
#  ('되어', 'Verb'),
#  ('있', 'PreEomi'),
#  ('는', 'PreEomi'),
#  ('데요', 'Eomi'),
#  ('!', 'Punctuation'),
#  ('파우더', 'Noun'),
#  ('타입', 'Noun'),
#  ('은', 'Josa'),
#  ('요즘', 'Noun'),
#  ('벨벳', 'Noun'),
#  ('텍스츄', 'Noun'),
#  ('어의', 'Noun'),
#  ('립', 'Noun'),
#  ('들', 'Suffix'),
#  ('이', 'Josa'),
#  ('유행하잖', 'Verb'),
#  ('아요', 'Eomi'),
#  ('!?', 'Punctuation'),
#  ('그것', 'Noun'),
#  ('처럼', 'Josa'),
#  ('속', 'Noun'),
#  ('은', 'Josa'),
#  ('그렇게', 'Adverb'),
#  ('건조하지', 'Adjective'),
#  ('않은', 'Verb'),
#  ('데', 'Eomi'),
#  ('겉', 'Noun'),
#  ('은', 'Josa'),
#  ('정말', 'Noun'),
#  ('뽀송하', 'Noun'),
#  ('게', 'Josa'),
#  ('마무리', 'Noun'),
#  ('되어서', 'Verb'),
#  ('좋', 'Adjective'),
#  ('았', 'PreEomi'),
#  ('어요', 'Eomi'),
#  ('.', 'Punctuation'),
#  ('정말', 'Noun'),
#  ('지성인', 'Noun'),
#  ('분', 'Noun'),
#  ('들', 'Suffix'),
#  ('에게', 'Josa'),
#  ('강력', 'Noun'),
#  ('추천', 'Noun'),
#  ('...', 'Punctuation'),
#  ('두', 'Determiner'),
#  ('번', 'Noun'),
#  ('추천', 'Noun'),
#  ('......', 'Punctuation'),
#  ('거기', 'Noun'),
#  ('다', 'Josa'),
#  ('컨실러', 'Noun'),
#  ('사용', 'Noun'),
#  ('도', 'Josa'),
#  ('필요없', 'Adjective'),
#  ('을', 'PreEomi'),
#  ('만큼', 'Eomi'),
#  ('커버', 'Noun'),
#  ('력', 'Suffix'),
#  ('이', 'Josa'),
#  ('좋', 'Adjective'),
#  ('아서', 'Eomi'),
#  (',', 'Punctuation'),
#  ('컨실러', 'Noun'),
#  ('+', 'Punctuation'),
#  ('쿠션', 'Noun'),
#  ('+', 'Punctuation'),
#  ('파우더', 'Noun'),
#  ('가', 'Josa'),
#  ('하나로', 'Noun'),
#  ('합쳐', 'Verb'),
#  ('져', 'PreEomi'),
#  ('진', 'Eomi'),
#  ('느낌', 'Noun'),
#  ('.....', 'Punctuation'),
#  ('인생', 'Noun'),
#  ('쿠션', 'Noun'),
#  ('...', 'Punctuation'),
#  ('앞', 'Noun'),
#  ('으로', 'Josa'),
#  ('쿠션', 'Noun'),
#  ('은', 'Josa'),
#  ('너', 'Noun'),
#  ('로', 'Josa'),
#  ('정했', 'Verb'),
#  ('다', 'Eomi'),
#  ('....!', 'Punctuation'),
#  ('그리고', 'Conjunction'),
#  ('마몽드', 'Noun'),
#  ('홈페이지', 'Noun'),
#  ('를', 'Josa'),
#  ('보', 'Noun'),
#  ('니까', 'Josa'),
#  (',', 'Punctuation'),
#  ('이제', 'Noun'),
#  ('곧', 'Noun'),
#  ('겨울', 'Noun'),
#  ('이', 'Josa'),
#  ('잖아', 'Verb'),
#  ('요', 'Eomi'),
#  ('?', 'Punctuation'),
#  ('시즌', 'Noun'),
#  ('에', 'Josa'),
#  ('맞춰', 'Verb'),
#  ('서', 'Eomi'),
#  ('앰', 'Noun'),
#  ('플', 'Exclamation'),
#  ('쿠션', 'Noun'),
#  ('도', 'Josa'),
#  ('새로', 'Adjective'),
#  ('출시', 'Noun'),
#  ('되었', 'Verb'),
#  ('더라구요', 'Eomi'),
#  ('!', 'Punctuation'),
#  ('겨울', 'Noun'),
#  ('건조한', 'Adjective'),
#  ('피부', 'Noun'),
#  ('를', 'Josa'),
#  ('보호하기', 'Verb'),
#  ('위한', 'Verb'),
#  ('앰', 'Noun'),
#  ('플', 'Exclamation'),
#  ('쿠션', 'Noun'),
#  ('!', 'Punctuation'),
#  ('테스', 'Noun'),
#  ('터', 'Noun'),
#  ('해보러', 'Verb'),
#  ('매장', 'Noun'),
#  ('방문해야', 'Verb'),
#  ('겠', 'PreEomi'),
#  ('어요', 'Eomi'),
#  ('!', 'Punctuation'),
#  ('ㅎㅎㅎ', 'KoreanParticle')]

# %%
#형태소분석 결과 저장하기

SAVE_MA_RESULTS = './ma/형태소분석결과_아리따움.txt'

with open(SAVE_MA_RESULTS, 'w', encoding='utf-8') as save:
    for ma_result in ma_results:
        for word in ma_result:
            save.write(word[0] + ',')   # 단어만 저장함
        save.write('\n')
    print('저장완료')
# Out:
# 저장완료

# %%
print(len(ma_results))  #300 개 본문 글 분석예정
# Out:
# 300

# %%
print(ma_results[4])
# Out:
# [('요즘', 'Noun'), ('화해', 'Noun'), ('도', 'Josa'), ('그렇', 'Adjective'), ('고', 'Eomi'), ('여기저기', 'Noun'), ('후기', 'Noun'), ('가', 'Josa'), ('좋', 'Adjective'), ('아서', 'Eomi'), ('한번', 'Noun'), ('써', 'Verb'), ('보고', 'Noun'), ('싶었', 'Verb'), ('는데', 'Eomi'), ('오프라인', 'Noun'), ('으로', 'Josa'), ('찾기', 'Noun'), ('힘들었', 'Adjective'), ('거든요', 'Eomi'), ('저번', 'Noun'), ('에', 'Josa'), ('아리따움', 'Noun'), ('에', 'Josa'), ('들어왔', 'Verb'), ('다고는', 'Eomi'), ('했', 'Verb'), ('는데', 'Eomi'), ('전부', 'Noun'), ('들어온', 'Verb'), ('건', 'Noun'), ('아니', 'Adjective'), ('더라구요', 'Eomi'), ('근데', 'Adverb'), ('이번', 'Noun'), ('에', 'Josa'), ('집', 'Noun'), ('근처', 'Noun'), ('왓슨스', 'Noun'), ('지나가다', 'Verb'), ('가', 'Eomi'), ('딱', 'Adverb'), ('마주친', 'Verb'), ('거', 'Noun'), ('있죠', 'Adjective'), ('??', 'Punctuation'), ('속', 'Noun'), ('건조', 'Noun'), ('100', 'Number'), ('%', 'Punctuation'), ('해결', 'Noun'), ('!!', 'Punctuation'), ('이', 'Noun'), ('문구', 'Noun'), ('랑', 'Josa'), ('말', 'Noun'), ('이', 'Suffix'), ('예요', 'Josa'), ('ㅎㅎㅎ', 'KoreanParticle'), ('다', 'Adverb'), ('들', 'Verb'), ('가온', 'Noun'), ('도담', 'Noun'), ('올인원', 'Noun'), ('크림', 'Noun'), ('이', 'Josa'), ('후기', 'Noun'), ('에서도', 'Josa'), ('그렇게', 'Adverb'), ('촉촉하다', 'Adjective'), ('고', 'Eomi'), ('하길', 'Verb'), ('래', 'Eomi'), ('제', 'Noun'), ('가', 'Josa'), ('또', 'Noun'), ('민감', 'Noun'), ('성', 'Suffix'), ('극', 'NounPrefix'), ('건성', 'Noun'), ('이', 'Josa'), ('거든', 'Verb'), ('요', 'Eomi'), ('ㅋㅋㅋ', 'KoreanParticle'), ('바로', 'Noun'), ('테스트', 'Noun'), ('해보고', 'Verb'), ('나쁘', 'Adjective'), ('지', 'Eomi'), ('않아', 'Verb'), ('서', 'Eomi'), ('사봤', 'Verb'), ('어요', 'Eomi'), ('며칠', 'Noun'), ('발랐는데', 'Noun'), ('정말', 'Noun'), ('촉촉하더', 'Adjective'), ('라고요', 'Eomi'), ('완전', 'Noun'), ('피부', 'Noun'), ('가', 'Josa'), ('쫀쫀하', 'Noun'), ('게', 'Josa'), ('자리', 'Noun'), ('잡는', 'Verb'), ('느낌', 'Noun'), ('이', 'Josa'), ('랄', 'Noun'), ('까', 'Verb'), ('?', 'Punctuation'), ('엄청', 'Adverb'), ('기름', 'Noun'), ('지고', 'Noun'), ('무거', 'Adjective'), ('울', 'PreEomi'), ('줄', 'Noun'), ('알', 'Verb'), ('았', 'PreEomi'), ('는데', 'Eomi'), ('생각', 'Noun'), ('보다', 'Josa'), ('무겁', 'Adjective'), ('진', 'Eomi'), ('않았', 'Verb'), ('어요', 'Eomi'), ('그리고', 'Conjunction'), ('성분', 'Noun'), ('진짜', 'Noun'), ('착하더', 'Adjective'), ('라고요', 'Eomi'), ('저', 'Determiner'), ('민감', 'Noun'), ('성', 'Suffix'), ('인데', 'Josa'), ('후기', 'Noun'), ('대로', 'Josa'), ('완전', 'Noun'), ('트러블', 'Noun'), ('안나', 'Noun'), ('요', 'Josa'), ('~', 'Punctuation'), ('좀', 'Noun'), ('더', 'Noun'), ('빨리', 'Adverb'), ('살', 'Noun'), ('걸', 'Noun'), ('그랬', 'Adjective'), ('다는', 'Eomi'), ('생각', 'Noun'), ('이', 'Josa'), ('들', 'Verb'), ('지만', 'Eomi'), ('그래도', 'Adverb'), ('지금', 'Noun'), ('세', 'Noun'), ('일하는', 'Verb'), ('가격', 'Noun'), ('으로', 'Josa'), ('샀', 'Verb'), ('으니', 'Eomi'), ('괜찮', 'Adjective'), ('아요', 'Eomi'), ('..', 'Punctuation'), ('괜찮', 'Adjective'), ('아', 'Eomi'), ('..', 'Punctuation'), ('유통', 'Noun'), ('기한', 'Noun'), ('넉넉하길', 'Adjective'), ('래', 'Eomi'), ('지금', 'Noun'), ('몇', 'Noun'), ('개', 'Noun'), ('더', 'Noun'), ('사서', 'Noun'), ('쟁', 'Noun'), ('여', 'Josa'), ('놓', 'Verb'), ('으려고요', 'Eomi'), ('~', 'Punctuation'), ('ㅎ', 'KoreanParticle')]

# %%
# 분석 대상 정리하기(원하는 품사 선택, STOPWORDS 제외)

# FILTER_IN_POSES=['NNG','NNP', 'XR']       # Komoran 기준
#NNG 일반명사  NNP 고유명사 XR 어근 (~하다) VA 형용사(~다)
# XR: 어근,  ~하다 ex.유쾌하다

FILTER_IN_POSES=['Noun']

STOPWORD=['으로','어요','!!','는데','있어','니다','에서','..','입니','하고','에요','데요','...','이에요','더라구요','인데',
         '까지','ㅎㅎ','데요','습니다','이라','그리고','이렇게','에는','000','아요','!!!','면서','이나']   #분석에서 제외할 단어 추가 필요


def ma_results_select(ma_results, FILTER_IN_POSES, STOPWORD):

    ma_results_selected=[]

    for ma_result in ma_results:
        ma_selected=[]
        for morph_lex, morph_cat in ma_result:
            if morph_lex not in STOPWORD: 
                ma_selected.append(morph_lex)

        ma_results_selected.append(ma_selected)

    return ma_results_selected

# %%
ma_results_selected = ma_results_select(ma_results, FILTER_IN_POSES, STOPWORD)

# %%
print(ma_results_selected[4])
# Out:
# ['요즘', '화해', '도', '그렇', '고', '여기저기', '후기', '가', '좋', '아서', '한번', '써', '보고', '싶었', '오프라인', '찾기', '힘들었', '거든요', '저번', '에', '아리따움', '에', '들어왔', '다고는', '했', '전부', '들어온', '건', '아니', '근데', '이번', '에', '집', '근처', '왓슨스', '지나가다', '가', '딱', '마주친', '거', '있죠', '??', '속', '건조', '100', '%', '해결', '이', '문구', '랑', '말', '이', '예요', 'ㅎㅎㅎ', '다', '들', '가온', '도담', '올인원', '크림', '이', '후기', '에서도', '그렇게', '촉촉하다', '고', '하길', '래', '제', '가', '또', '민감', '성', '극', '건성', '이', '거든', '요', 'ㅋㅋㅋ', '바로', '테스트', '해보고', '나쁘', '지', '않아', '서', '사봤', '며칠', '발랐는데', '정말', '촉촉하더', '라고요', '완전', '피부', '가', '쫀쫀하', '게', '자리', '잡는', '느낌', '이', '랄', '까', '?', '엄청', '기름', '지고', '무거', '울', '줄', '알', '았', '생각', '보다', '무겁', '진', '않았', '성분', '진짜', '착하더', '라고요', '저', '민감', '성', '후기', '대로', '완전', '트러블', '안나', '요', '~', '좀', '더', '빨리', '살', '걸', '그랬', '다는', '생각', '이', '들', '지만', '그래도', '지금', '세', '일하는', '가격', '샀', '으니', '괜찮', '괜찮', '아', '유통', '기한', '넉넉하길', '래', '지금', '몇', '개', '더', '사서', '쟁', '여', '놓', '으려고요', '~', 'ㅎ']

# %%
# 워드클라우드 만들기
# %matplotlib inline

from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# most common 단어 정리

WORDS_NUMBER = 100    # most common 단어 개수

def find_words_most(ma_results_selected, words_number):
    words_count=Counter()
    
    for ma_results in ma_results_selected:      
        words_count.update(ma_results)   # , 로 분류된 단어들은 한번에 들어감

    words_most = []
    
    for word,count in words_count.most_common(words_number):
        if len(word) >=2 :   #한자리 단어는 제외
            words_most.append((word,count))
    
    return words_most

# %%
words_most = find_words_most(ma_results_selected, 200)

# %%
print(words_most)
# Out:
# [('컬러', 1427), ('아리따움', 1144), ('제품', 822), ('틴트', 626), ('느낌', 606), ('발색', 583), ('피부', 505), ('색상', 451), ('메이크업', 448), ('발라', 401), ('있는', 399), ('핑크', 387), ('같아', 363), ('레드', 354), ('입술', 335), ('바르', 330), ('가지', 320), ('섀도우', 320), ('포인트', 318), ('정말', 315), ('너무', 311), ('사용', 286), ('크림', 282), ('오렌지', 275), ('네일', 272), ('진짜', 271), ('뷰티', 262), ('아이즈', 244), ('젤리', 234), ('코랄', 230), ('같은', 220), ('모디', 213), ('브라운', 210), ('하나', 206), ('ㅋㅋㅋ', 206), ('오일', 204), ('보여', 203), ('모노', 202), ('ㅋㅋ', 202), ('이번', 201), ('하는', 199), (':)', 198), ('가격', 197), ('보다', 197), ('타입', 195), ('되어', 192), ('구매', 185), ('되는', 182), ('많이', 177), ('부분', 173), ('하게', 167), ('에도', 166), ('지만', 166), ('아니', 165), ('아이', 161), ('하면', 160), ('해서', 160), ('정도', 159), ('부터', 158), ('베이지', 156), ('살짝', 156), ('라구요', 150), ('때문', 149), ('얼굴', 147), ('한번', 147), ('완전', 143), ('그라데이션', 142), ('일리', 142), ('마스크', 141), ('약간', 140), ('화장', 139), ('처럼', 139), ('팔레트', 139), ('없이', 138), ('오늘', 136), ('네요', 132), ('예쁘', 131), ('사진', 131), ('다른', 131), ('바로', 129), ('들어', 126), ('워터', 126), ('ㅠㅠ', 125), ('추천', 125), ('이벤트', 125), ('보습', 124), ('베이스', 123), ('가장', 121), ('않아', 120), ('게요', 120), ('요즘', 120), ('지속', 119), ('출시', 119), ('예요', 119)]

# %%
#워드클라우드 그리기(화이트)

# %matplotlib inline
import sys

def make_word_cloud(words):
    
    # 폰트 설정
    if sys.platform in ["win32", "win64"]:
        font_path = "c:/Windows/Fonts/malgun.ttf"
    elif sys.platform == "darwin":
        fornt_path = "c:/Windows/Fonts/AppleGothic.ttf"

    tmp = dict(words)
    wordcloud=WordCloud(font_path=font_path, relative_scaling=0.3, 
                        background_color="white", max_words=50,
                       font_step=10).generate_from_frequencies(tmp)
    
    plt.figure(figsize=(16,8))
    plt.imshow(wordcloud)
    plt.axis('off')

    #파일명 확인 필요
    plt.savefig('./result/아리따움_워드클라우드_white.png')

# %%
make_word_cloud(words_most)

# %%
# 워드 SNS 분석

from collections import Counter
from itertools import combinations

def word_cooc_matrics(contents):
    
    word_cooc_mat=Counter()

    for line in contents:
        for word1, word2 in combinations(line,2):
            if word1 == word2 :   #동일한 단어간의 벡터는 계산하지 않음
                continue
            elif word_cooc_mat[(word2,word1)]>=1:    # 동일한 조합이나, 순서가 반대인 경우 하나의 조합으로만 카운트함
                word_cooc_mat[(word2,word1)]+=1
            else:
                word_cooc_mat[(word1,word2)]+=1
    
    return word_cooc_mat

# %%
print(word_cooc_matrics(ma_results_selected))
word_cooc_mat = word_cooc_matrics(ma_results_selected)

# %%
from konlpy.tag import Komoran

# %%
#데이터 불러오기.  한줄에 댓글 하나 → 리스트로 댓글별 저장
INPUT_FILE = './data/크롤링결과_total.txt'

datas=[]
with open(INPUT_FILE, "r", encoding='utf-8') as input_file:
    for line in input_file:
        if len(line) > 3:      # 줄간격 및 공백은 삭제
#             print(len(line))
            datas.append(line.strip())
#     data=input_file.read()

print(len(datas))
print(datas[:10])
# Out:
# 632
# ['정말 힘들어 죽을 것 같습니다. 위치는 영등포역 이훈30000미용실 유흥업소??가 있는 골목이죠.. 이 길이 출근길인데 아침마다 업소여성들이 비둘기 밥을줘요 불법으로 알고있어서 경찰서에 신고했더니 구청에 신고하라고 하시더라구요 ㅠㅠ해결 부탁드립니다 ㅠㅠ', '선유로 207 양평동6차현대A앞 미관지구 건축선 후퇴선 인도에 주민통행 불편와 미관을 해치는 무분별한 주차 금지 및 소화전 보호를 위하여 소화전앞에 차량이 진입하지 못하도록 진입 금지봉 설치를 요청합니다. 아울러 주차 위반 단속도 요청합니다. 소화전에는 반경 3M이내에는 주차금지구역으로 알고 있습니다.', '과거 새길어린이집앞  도로를 1996년 영등포구청 소유권 이전후 현재까지 개인 사유지처럼 불법점용되고 있고, 주민들은 이 같은 사실조차 알지못하고 있습니다 이 불법점용사용자들에 대한 점용료 부과와 이 토지에 대해 보도블럭등을 깔거나 버스정류장 대기시설을 짓던지 하는 방법으로 도로 관리 철저히 해주세요 불법점용사진은 이미 여러장 확보했으니 엉터리 답변할 생각하지마세요', '불철 주야 고생이  많으십니다 요즘같은 날  감기조심하시고 좀더 세심한 홈페이지 관리를 부탁 드립니다,불법주차관련이 있다고해도 어르신들은 볼수가 있겠는지 그런생각이 듭니다 제일 싸움도 많고 하는문제인데 정작 중요한 부분은 소홀 하신듯 합니다,, 전 40중후반 반 영등포 주민 입니다 이동네 산지도 40년이넘었는데 어느날부터 사람들이 많은 관계로 저의 개인 사유지 인데도 불구하고 매일 주차 문제로 싸우고 해야 하는 이점 많은 고충이 있습니다 참저는 참고로 제차도 없습니다..ㅎㅎ80대 노모랑 함께 생활 하는 저로서는 너무나 불편 해요 개인 사유지인데도 불구 하고 ,물어보지도 않고 아스팔트를깔고 도로도 아닌데 어느날 보니 도로 지명 돼있고 ㅎ 도로 편의를위해 관습도로라해서 사람다니는 것까지는 좋아요 좋습니다만. 차를 주차해서 생기는 불편 너무 심합니다,,매일 싸워야 되니요 좁은 도로에 주차를 하면 너무 불편하거든요 함 관계를 보시면 지적도를 보시면 개인 사유지인데도 불구하고 관습도로라 어쩔수 없이 살고 있습니다만은 너무나 주차 문제로 시끄러운니 구청에서 주차만 못하게 해줄수 있는지요?수차례 구청 을방문 했으나 그분 말이 ;사유지인데 막으시라는 분도 계시고 이분은 모르시는 말씀만 하시고 관계자가 더욱 요..좀 신경 써주시길  부탁드립니다 민원은 발생이 가장 빈번 하고 큰데 있다봅니다 부탁 드립니다 구청장님 구청장님 바뀌시고 해서 좀 달라지나 했
나요.   왜 0세어린이는 길거리에 내던지신건가요? 0세어린이는 구청의 정책에는 전혀 대상이아닌건가요? 지금 아이를 가진 제 원죄라는 뜻이신가요?    국가의 어떤 도움을 바라고 국가의 보호를 바래야하는 건가요.    나만 우리아가만 아크로주민의 0세아가들만 왜 이런 피눈물의 대상이 되어야하는지요.  아크로만 보고 입주하고 기대하고있던 영등포구에 전입한 제 탓으로 생각하라는 것으로 생각해야하는것인지요.', '어제 래미안에스티움 아파트에서 최고야 식자재마트로 가는 횡단보도에서 사고가 있었습니다. 처음에 사고 영상을 봤을 때는 운전자의 부주의라고만 생각했습니다.  근데 영상을 다시 보고 생각을 해 보니  큰 버스가 사고차량 앞에서 주행 중이였고 맞은편에는 큰 봉고가 오고 있었고 어린아이는 퀵보드를 타고 횡단 보도를 건너고 있었기 때문에 운전자가 어린아이를 볼 수 없었을 수 있었을 것 같다는 생각이 들었습니다. 큰 버스가 앞에서 주행 하고 있었기 때문에 시야가 많이 가려졌을 테고 아이가 횡단보도에서 출발했을 때는 맞은편에서 오던 큰 봉고가 운전자의 시야를 가렸을 테고 아이는 퀵보드를 타고 있었기 때문에 반대편 차선까지 빨리 도달했고 그래서 운전자가 아이를 발견한 시점이 매우 늦었을 것입니다. 아이의 속도가 조금만 더 빨랐더라면 정면으로 충돌 했을텐데 천만 다행으로 정면 충돌은 아니였습니다.  물론 퀵보드를 타고 횡단보도를 건넌 것도 문제일 수도 있고 운전자가 정말로 전방주시에 주의를 기울이지 않았던 문제일 수도 있습니다. 하지만 신호등이 없는 횡단보도라는 점과 사각지대가 만들어질 수 있는 상황에서 대한 부분을 간과할 수는 없을 것입니다.  많은 신호등이 교통체증의 원인으로 작용하기도 한다는 것도 알고 있고 원하는곳에 신호등을 모두 세우기에는 예산의 문제도 있다는 것을 알고 있습니다. 하지만 주택가나 학교 근방은 아이들의 보행이 많고 이렇게 사각지대가 만들어질 경우 사실 어른 입장에서도 사고를 피하기 어려운 상황이 많은데 아이들의 경우는 더더욱 어려울 것 입니다.  구청장님께 이곳에 신호등을 설치를 위해 노력을 해 주십사 하고 간곡히 부탁드립니다.  교통사고는 가해나나 피해자 모두에게 큰 재앙입니다.', '항상 영등포역으로 출근하면서 수많은 노점상을 보면 영등포의 얼굴인 영등포역에 이렇게 비위생적인으로 운영되는 노점을 방치,묵인한다는것은 구청장님이 우리 구청장이 맞는지 의심하였습니다.  도대체 어디서 물을 구하고 설겆이는 어떻게 하는지? 쥐가 들락달락하는건 아시는지?  구민의 건강은 생각해 보셨는지? 비가 올때면 노점상이 점점 도로를 침범하였기에 다닐수 조차 없는 도로?  오물에  쩌러있는 포장들?  비위생적인 ...

# %%
# 댓글별 형태소 분석하기

ma_results = []
komoran = Komoran()

for line in datas:
    ma_by_line=komoran.pos(line)
    ma_results.append(ma_by_line)

#gprint(ma_results)

# %%
#형태소분석 결과 저장하기
OUTPUT_ma_results = './data_구청장/형태소분석결과.txt'

with open(OUTPUT_ma_results, "w", encoding='utf-8') as output:
    for person in ma_results:
        for word in person:
            output.write(word[0]+',')
        output.writelines('\n')
    print('저장완료')
# Out:
# 저장완료

# %%
print(len(ma_results)) #632개의 게시글 분석
# Out:
# 632

# %%
print(ma_results[3])
print(type(ma_results[3]))
# Out:
# [('불', 'XPN'), ('철', 'NNG'), ('주', 'VX'), ('야', 'EC'), ('고생', 'NNG'), ('이', 'JKS'), ('많', 'VA'), ('으시', 'EP'), ('ㅂ니다', 'EC'), ('요즘', 'NNG'), ('같', 'VA'), ('은', 'ETM'), ('날', 'NNG'), ('감기', 'NNG'), ('조심', 'NNG'), ('하', 'XSV'), ('시', 'EP'), ('고', 'EC'), ('좀', 'MAG'), ('더', 'MAG'), ('세심', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('홈페이지', 'NNG'), ('관리', 'NNG'), ('를', 'JKO'), ('부탁', 'NNG'), ('드리', 'VV'), ('ㅂ니다', 'EC'), (',', 'SP'), ('불법', 'NNG'), ('주차', 'NNG'), ('관련', 'NNG'), ('이', 'JKS'), ('있', 'VV'), ('다고', 'EC'), ('하', 'VX'), ('아도', 'EC'), ('어르신', 'NNG'), ('들', 'XSN'), ('은', 'JX'), ('보', 'VV'), ('ㄹ', 'ETM'), ('수', 'NNB'), ('가', 'JKS'), ('있', 'VX'), ('겠', 'EP'), ('는지', 'EC'), ('그런', 'MM'), ('생각', 'NNG'), ('이', 'JKS'), ('어', 'EC'), ('들', 'VX'), ('ㅂ니다', 'EC'), ('제일', 'NNG'), ('싸움', 'NNG'), ('도', 'JX'), ('많', 'VA'), ('고', 'EC'), ('하', 'VV'), ('는', 'ETM'), ('문제', 'NNG'), ('이', 'VCP'), ('ㄴ데', 'EC'), ('정작', 'NNG'), ('중요', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('부분', 'NNG'), ('은', 'JX'), ('소홀', 'NNG'), ('하', 'VV'), ('시', 'EP'), ('ㄴ듯', 'EC'), ('하', 'VV'), ('ㅂ니다', 'EC'), (',', 'SP'), (',', 'SP'), ('전', 'MM'), ('40', 'SN'), ('중후반', 'NNG'), ('반', 'NNG'), ('영등포', 'NNP'), ('주민', 'NNG'), ('이', 'VV'), ('ㅂ니다', 'EC'), ('이', 'MM'), ('동네', 'NNG'), ('산지', 'NNG'), ('도', 'JX'), ('40', 'SN'), ('년', 'NNB'), ('이', 'JKS'), ('넘', 'VV'), ('었', 'EP'), ('는데', 'EC'), ('어느', 'MM'), ('날', 'NNG'), ('부터', 'JX'), ('사람', 'NNG'), ('들', 'XSN'), ('이', 'JKS'), ('많', 'VA'), ('은', 'ETM'), ('관계', 'NNG'), ('로', 'JKB'), ('저', 'NP'), ('의', 'JKG'), ('개인', 'NNG'), ('사유지', 'NNG'), ('일', 'VV'), ('ㄴ데', 'EC'), ('도', 'JX'), ('불구', 'XR'), ('하', 'XSA'), ('고', 'EC'), ('매일', 'MAG'), ('주차', 'NNG'), ('문제', 'NNG'), ('로', 'JKB'), ('싸우', 'VV'), ('고', 'EC'), ('하', 'VV'), ('아야', 'EC'), ('하', 'VV'), ('는', 'ETM'), ('이점', 'NNG'), ('많', 'VA'), ('은', 'ETM'), ('고충', 'NNG'), ('이', 'JKS'), ('있', 'VV'), ('습니다', 'EC'), ('참', 'IC'), ('저', 'NP'), ('는', 'JX'), ('참고', 'NNG'), ('로', 'JKB'), ('제', 'XPN'), ('차', 'NNG'), ('도', 'JX'), ('없습니다..ㅎㅎ80대', 'NA'), ('노모', 'NNG'), ('랑', 'JKB'), ('함께', 'MAG'), ('생활', 'NNG'), ('하', 'VV'), ('는', 'ETM'), ('저', 'NP'), ('로서', 'JKB'), ('는', 'JX'), ('너무나', 'MAG'), ('불편', 'NNG'), ('하', 'VV'), ('아요', 'EC'), ('개인', 'NNG'), ('사유지', 'NNG'), ('이', 'VCP'), ('ㄴ데', 'EC'), ('도', 'JX'), ('불구', 'XR'), ('하', 'VV'), ('고', 'EC'), (',', 'SP'), ('물어보', 'VV'), ('지', 'EC'), ('도', 'JX'), ('않', 'VX'), ('고', 'EC'), ('아스팔트', 'NNG'), ('를', 'JKO'), ('깔', 'VV'), ('고', 'EC'), ('도로', 'NNG'), ('도', 'JX'), ('아니', 'VCN'), ('ㄴ데', 'EC'), ('어느', 'MM'), ('날', 'NNG'), ('보', 'VV'), ('니', 'EC'), ('도로', 'MAG'), ('지명', 'NNG'), ('되', 'VV'), ('어', 'EC'), ('있', 'VX'), ('고', 'EC'), ('ㅎ', 'NA'), ('도로', 'MAG'), ('편의', 'NNG'), ('를', 'JKO'), ('위하', 'VV'), ('아', 'EC'), ('관습', 'NNG'), ('도로', 'NNG'), ('이', 'VCP'), ('라', 'EC'), ('하', 'VX'), ('아서', 'EC'), ('사람', 'NNG'), ('다니', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('까지', 'JX'), ('는', 'JX'), ('좋', 'VA'), ('아요', 'EC'), ('좋', 'VA'), ('습니다만', 'EF'), ('.', 'SF'), ('차', 'NNG'), ('를', 'JKO'), ('주차', 'NNG'), ('하', 'XSV'), ('아서', 'EC'), ('생기', 'VV'), ('는', 'ETM'), ('불편', 'NNG'), ('너무', 'MAG'), ('심하', 'VA'), ('ㅂ니다', 'EC'), (',', 'SP'), (',', 'SP'), ('매일', 'NNG'), ('싸우', 'VV'), ('어야', 'EC'), ('되', 'VV'), ('니', 'EC'), ('요', 'JX'), ('좁', 'VA'), ('은', 'ETM'), ('도로', 'NNG'), ('에', 'JKB'), ('주차', 'NNG'), ('를', 'JKO'), ('하', 'VV'), ('면', 'EC'), ('너무', 'MAG'), ('불편', 'NNG'), ('하', 'XSV'), ('거든요', 'EC'), ('하', 'VV'), ('ㅁ', 'ETN'), ('관계', 'NNG'), ('를', 'JKO'), ('보', 'VV'), ('시', 'EP'), ('면', 'EC'), ('지적도', 'NNP'), ('를', 'JKO'), ('보', 'VV'), ('시', 'EP'), ('면', 'EC'), ('개인', 'NNG'), ('사유지', 'NNG'), ('이', 'VCP'), ('ㄴ데', 'EC'), ('도', 'JX'), ('불구', 'XR'), ('하', 'XSA'), ('고', 'EC'), ('관습', 'NNG'), ('도로', 'NNG'), ('이', 'VCP'), ('라', 'EC'), ('어쩌', 'VV'), ('ㄹ', 'ETM'), ('수', 'NNB'), ('없이', 'MAG'), ('살', 'VV'), ('고', 'EC'), ('있', 'VV'), ('습니다만', 'EC'), ('은', 'JX'), ('너무나', 'MAG'), ('주차', 'NNG'), ('문제', 'NNG'), ('로', 'JKB'), ('시끄럽', 'VA'), ('ㄴ', 'ETM'), ('니', 'EC'), ('구청', 'NNG'), ('에서', 'JKB'), ('주차', 'NNG'), ('만', 'JX'), ...
# <class 'list'>

# %%
# 댓글별 원하는 품사만 저장하기
# STOPWORD 제외하기

FILTER_IN_POSES=['NNG','NNP']   
# FILTER_IN_POSES_AD1=['XR']     #어근.~하다 ex) 유쾌  
# FILTER_IN_POSES_AD2=['VA']      #형용사. ~다 ex) 쉽, 어렵
FILTER_IN_POSES_AD1=[]    #명사만 테스트
FILTER_IN_POSES_AD2=[]    #명사만 테스트

#NNG 일반명사  NNP 고유명사 XR 어근 (~하다) VA 형용사(~다)
STOPWORD=[]   #분석에서 제외할 단어 추가 필요

ma_results_selected=[]

for ma_result in ma_results:
    ma_selected=[]
    for morph_lex, morph_cat in ma_result:
        if morph_lex in STOPWORD:
            continue
        elif morph_cat in FILTER_IN_POSES:   # 일반명사이거나 고유명사일 경우 포함한다
            ma_selected.append(morph_lex)   
        elif morph_cat in FILTER_IN_POSES_AD1:
            ma_selected.append(morph_lex+'하다')
        elif morph_cat in FILTER_IN_POSES_AD2:
            ma_selected.append(morph_lex+'다')
        else:
            continue
        ma_selected=list(set(ma_selected))   #중복은 제외: 한 사람이 동일한 단어 여러번 이야기 했을 경우 제외함
    ma_results_selected.append(ma_selected)
    
print(ma_results_selected[:5])
# Out:
# [['위치', '미용실', '골목', '영등포역', '길', '불법', '경찰서', '아침', '밥', '유흥업소', '신고', '업소', '부탁', '여성', '구청', '이훈', '출근길', '비둘기'], ['선유로', '이내', '진입', '지구', '소화전', '미관', '양평동', '요청', '후퇴', '통행', '봉', '설치', '위반', '주민', '금지', '단속', '인도', '선', '현대', '분별', '반경', '앞', '불편', '보호', '주차', '구역', '건축', '차량'], ['이전', '토지', '후', '사용자', '과거', '답변', '엉터리', '불법', '점', '확보', '소유권', '생각', '주민', '부과', '대기', '도로', '집', '현재', '어린이', '방법', '새길', '사진', '시설', '앞', '영등포구청', '블럭', '버스정류장', '관리', '사실', '보도', '개인', '사유지'], ['요', '제일', '민원', '사람', '매일', '을', '차', '반', '관습', '자동차', '어머니', '날', '어르신', '관련', '고생', '수차례', '수수방관', '잠', '소홀', '발생', '불법', '지명', '길', '시정', '홈페이지', '감기', '관계', '아스팔트', '조심', '표', '생각', '주민', '문', '철', '말씀', '문제', '싸움', '구청장', '도로', '집', '조치', '마당', '이점', '가요', '생활', '노모', '동네', '편의', '사진', '요즘', '산지', '영등포', '말', '감사합니다', '부탁', '정작', '중후반', '지적도', '방문', '감사', '불편', '관계자', '고충', '관리', '참고', '주차', '글', '신경', '사유지', '유도', '구청', '표시', '부분', '개인', '차량'], ['쟁점', '검찰', '소송', '별개', '귀청', '방해', '토지', '당사자', '번호', '건축법', '패소', '관련', '허가', '서류', '통해', '의사', '장애물', '처리', '소유자', '과정', '참가', '부족', '진행', '본인', '적법성', '이유', '입장', '위반', '시정', '행정', '증거', '처분', '주장', '부칙', '표명', '당시', '혐의', '결과', '연계', '조항', '도로', '금지', '사건', '작위', '침범', '상항', '입증', '최근', '건물', '제거', '여부', '개정', '선', '교통', '주', '신청', '조병기', '건축물', '고지', '판단', '영향', '영등포구청', '대상', '행정소송', '아', '신길', '행정부', '형사', '가처분', '차단', '판결문', '건축', '공개', '행정처분', '의거', '임차인', '불복', '사유지']]

# %%
#형태소분석 결과 저장하기
# OUTPUT_ma_results = './data_구청장/형태소분석결과_명사어근형용사만.txt'
OUTPUT_ma_results = './data_구청장/형태소분석결과_명사만.txt'

with open(OUTPUT_ma_results, "w", encoding='utf-8') as output:
    for person in ma_results_selected:
            for word in person:
                output.write(word+',')
            output.writelines('\n')
            
    print('저장완료')
# Out:
# 저장완료

# %%
###잠깐 딴 짓. 워드클라우드 만들기

from collections import Counter

# 빈도 높은 단어들만 가져오기
words_count=Counter()
for ma_selected in ma_results_selected:
    words_count.update(ma_selected)

# print(words_count)    
    
words_most = []
words_most_onlyword=[]
for word,count in words_count.most_common(500):
    words_most.append((word,count))
    words_most_onlyword.append(word)
    
print(words_most[:100])
# Out:
# [('주민', 203), ('구청장', 202), ('앞', 189), ('민원', 180), ('생각', 172), ('구청', 171), ('감사', 165), ('영등포', 163), ('사람', 160), ('영등포구', 152), ('안', 149), ('부탁', 148), ('요청', 148), ('답변', 148), ('지역', 140), ('설치', 134), ('아파트', 131), ('길', 130), ('때', 126), ('곳', 125), ('안녕하세요', 118), ('말', 116), ('조치', 114), ('문제', 109), ('확인', 109), ('영등포구청', 108), ('단속', 106), ('사항', 106), ('불편', 103), ('불법', 102), ('경우', 100), ('집', 99), ('주변', 99), ('도로', 98), ('공사', 98), ('일', 98), ('관련', 97), ('상황', 97), ('신길', 96), ('시간', 96), ('아이', 95), ('전', 92), ('공무원', 92), ('글', 91), ('후', 90), ('처리', 89), ('진행', 89), ('정도', 87), ('해당', 87), ('주차', 85), ('차량', 85), ('사진', 85), ('필요', 85), ('옆', 83), ('내용', 83), ('전화', 83), ('첨부', 82), ('구역', 80), ('행정', 77), ('관리', 76), ('이유', 75), ('이용', 75), ('해결', 73), ('법', 72), ('구민', 70), ('시설', 68), ('현장', 67), ('건물', 66), ('제기', 66), ('담당', 66), ('말씀', 65), ('안녕하십니까', 65), ('발생', 63), ('허가', 63), ('결과', 63), ('이해', 63), ('위', 63), ('차', 62), ('피해', 62), ('직원', 62), ('거주', 61), ('안전', 61), ('담당자', 59), ('이상', 59), ('밖', 59), ('아침', 56), ('오늘', 56), ('운영', 56), ('업무', 56), ('주택', 56), ('소음', 56), ('주차장', 56), ('시정', 55), ('상태', 55), ('위반', 54), ('사실', 53), ('환경', 53), ('위험', 53), ('부과', 52), ('동네', 52)]

# %%
print(words_most_onlyword[:200])
# Out:
# ['주민', '구청장', '앞', '민원', '생각', '구청', '감사', '영등포', '사람', '영등포구', '안', '부탁', '요청', '답변', '지역', '설치', '아파트', '길', '때', '곳', '안녕하세요', '말', '조치', '문제', '확인', '영등포구청', '단속', '사항', '불편', '불법', '경우', '집', '주변', '도로', '공사', '일', '관련', '상황', '신길', '시간', '아이', '전', '공무원', '글', '후', '처리', '진행', '정도', '해당', '주차', '차량', '사진', '필요', '옆', '내용', '전화', '첨부', '구역', '행정', '관리', '이유', '이용', '해결', '법', '구민', '시설', '현장', '건물', '제기', '담당', '말씀', '안녕하십니까', '발생', '허가', '결과', '이해', '위', '차', '피해', '직원', '거주', '안전', '담당자', '이상', '밖', '아침', '오늘', '운영', '업무', '주택', '소음', '주차장', '시정', '상태', '위반', '사실', '환경', '위험', '부과', '동네', '마음', '구', '서울시', '관심', '건축', '부분', '주시', '의견', '사용', '센터', '요구', '문의', '발전', '지금', '위치', '방문', '검토', '조합', '예정', '신고', '행위', '과태료', '개선', '판단', '일반', '공원', '신길동', '입장', '철거', '다음', '주택조합', '이전', '현재', '학교', '장소', '구정', '통행', '날', '방치', '기준', '시민', '아래', '방법', '규정', '노력', '물', '변경', '조길형', '모습', '개인', '귀청', '본인', '이번', '이야기', '사이', '문', '최근', '신청', '사고', '달', '현수막', '하루', '거리', '쓰레기', '사업', '양평동', '생활', '공개', '입주', '뉴타운', '책임', '시작', '서울', '이후', '인근', '추진', '번지', '먼지', '인도', '일부', '끝', '지속', '동', '추가', '신경', '번호', '교육', '초등학교', '공간', '소리', '동안', '을', '여부', '건축물', '대상', '이사', '적극', '분양', '학생', '기간']

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from wordcloud import WordCloud

tmp = dict(words_most)
wordcloud=WordCloud(font_path="c:/Windows/Fonts/malgun.ttf", relative_scaling=0.3, 
                    background_color="white", max_words=50,
                   font_step=10).generate_from_frequencies(tmp)
plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('./data_구청장/wordcloud(white)_명사만.png')

# %%
# 벡터행렬 생성하기

from collections import Counter

# %%
# 취소
# 단어 관계 행렬 만들기  1씩 깔아놓기

from itertools import combinations

word_cooc_mat=Counter()

for word1, word2 in combinations(words_most_onlyword,2):
    word_cooc_mat[(word1,word2)]+=1

# %%
print(word_cooc_mat)
# Out:
# Counter({('문제점', '독일인'): 1, ('도서관', '언론'): 1, ('조금', '근처'): 1, ('도로', '불균형'): 1, ('계획', '도로'): 1, ('폭행', '간판'): 1, ('공원', '중국인'): 1, ('안녕하세요', '동시'): 1, ('일', '대방동'): 1, ('방', '독점'): 1, ('시급하다', '건너'): 1, ('자전거', '교사'): 1, ('유흥', '발생'): 1, ('규모', '소음'): 1, ('공용', '철거'): 1, ('후', '뉴스'): 1, ('신길동', '설치'): 1, ('좁다', '임지연'): 1, ('이미지', '그렇다'): 1, ('발전', '불길하다'): 1, ('자체', '노현'): 1, ('안전장치', '밀집'): 1, ('교통체증', '살인'): 1, ('유치원 선생님', '마련'): 1, ('강당', '후'): 1, ('없다', '유치원'): 1, ('안', '비싸다'): 1, ('예산', '입장료'): 1, ('지역', '새마을운동'): 1, ('생활', '주차장'): 1, ('주민', '낙후'): 1, ('유치원 선생님', '중국인'): 1, ('계획', '새마을운동'): 1, ('공인', '예방'): 1, ('구미', '이용'): 1, ('유치원', '계룡시'): 1, ('조성', '소음'): 1, ('문제', '낙후'): 1, ('정비', '확충'): 1, ('실정', '설치'): 1, ('안전장치', '중국인'): 1, ('마을', '문래동'): 1, ('재건축', '
'): 1, ('매체', '개발'): 1, ('방향', '협박'): 1, ('낙후', '일'): 1, ('거부', '자전거'): 1, ('계획', '매점'): 1, ('비싸다', '마을버스'): 1, ('어린이', '놀이'): 1, ('구미', '층'): 1, ('지역', '불길하다'): 1, ('고령화', '주거'): 1, ('어린이', '언급'): 1, ('방', '자전거'): 1, ('없다', '시설'): 1, ('낙후', '학군'): 1, ('신길동', '노현'): 1, ('임대', '근처'): 1, ('구미', '교통체증'): 1, ('초중고', '살인'): 1, ('마을', '근처'): 1, ('속도위반', '즐겁다'): 1, ('지역', '곳'): 1, ('친절', '차등'): 1, ('층', '주차장'): 1, ('마을버스', '군인'): 1, ('버스정류장', '카페나'): 1, ('표시', '책'): 1, ('재건축', '엄마'): 1, ('관리', '카페나'): 1, ('운영', '안녕하세요'): 1, ('서울시', '교사'): 1, ('어떻다', '균일'): 1, ('인성', '수준'): 1, ('균일', '카페나'): 1, ('안', '소음'): 1, ('실정', '이용'): 1, ('폭행', '개발'): 1, ('도서관', '변화'): 1, ('아파트', '복지관'): 1, ('개선', '공장'): 1, ('좁다', '인성'): 1, ('길', '층간소음'): 1, ('때', '프랑스'): 1, ('아파트', '생활'): 1, ('관', '군인'): 1, ('주차', '관광'): 1, ('마을버스', '자전거'): 1, ('신길동', '모델링'): 1, ('환경', '주차공간'): 1, ('밝다', '새마을운동'): 1, ('육성', '언급'): 1, ('요즘', '단지'): 1, ('층', '명문'): 1, ('복지', '발생'): 1, ('버스', '호텔'): 1, ('문제점', '예방'): 1, ('공유', '고가도로'): 1, ('카페', '크다'): 1, ('육성', '언론'): 1, ('교류', '대문'): 1, ('안', '발전'): 1, ('노력', '거리'): 1, ('시급하다', '공인'): 1, ('깨끗하다', '계룡시'): 1, ('버스', '엄마'): 1, ('전반', '어렵다'): 1, ('골목길', '명문'): 1, ('상점', '빠르다'): 1, ('매점', '거부'): 1, ('없다', '곳'): 1, ('어린이', '엄마'): 1, ('자신', '재건축'): 1, ('안전', '새마을운동'): 1, ('설치', '수준'): 1, ('층간소음', '낯설다'): 1, ('자체',  ...

# %%
# 단어 관계 행렬 쓰기 
from collections import Counter
from itertools import combinations

word_cooc_mat=Counter()

for line in ma_results_selected:
    for word1, word2 in combinations(line,2):
#         print(word1, word2)
        word_cooc_mat[(word1,word2)]+=1

# %%
print(word_cooc_mat)
# Out:
# Counter({('영등포구', '문제'): 5, ('생각', '좋다'): 5, ('문제', '시급하다'): 4, ('문제', '좋다'): 4, ('영등포구', '해결'): 4, ('같다', '좋다'): 4, ('영등포구', '실정'): 4, ('생각', '많다'): 4, ('생각', '영등포'): 4, ('깨끗하다', '골목'): 3, ('같다', '문제'): 3, ('영등포구', '좋다'): 3, ('요즘', '좋다'): 3, ('영등포', '좋다'): 3, ('해결', '문제'): 3, ('좋다', '많다'): 3, ('부족', '영등포'): 3, ('문제', '많다'): 3, ('영등포구', '많다'): 3, ('깨끗하다', '생각'): 3, ('영등포', '많다'): 3, ('생각
결', '자체'): 2, ('영등포구', '복지'): 2, ('깨끗하다', '같다'): 2, ('공간', '영등포'): 2, ('실정', '많다'): 2, ('아파트', '많다'): 2, ('정비', '시급하다'): 2, ('요즘', '공원'): 2, ('요즘', '공간'): 2, ('깨끗하다', '정비'): 2, ('층간소음', '문제'): 2, ('공간', '확충'): 2, ('집', '문제'): 2, ('지역', '좋다'): 2, ('공원', '생각'): 2, ('영등포구', '어르신'): 2, ('부족', '영등포구'): 2, ('집', '같다'): 2, ('영등포구', '이사'): 2, ('같다', '시급하다'): 2, ('요즘', '문제'): 2, ('생각', '문제'): 2, ('해결', '위'): 2, ('문제', '어린이'): 2, ('아이', '많다'): 2, ('쓰레기', '생각'): 2, ('문제점', '자체'): 2, ('집', '골목'): 2, ('영등포구', '위'): 2, ('영등포구', '지역'): 2, ('어린이', '많다'): 2, ('복지', '어르신'): 2, ('영등포구', '어떻다'): 2, ('마을', '자체'): 2, ('마을', '해결'): 2, ('생활', '어르신'): 2, ('대림동', '자체'): 2, ('깨끗하다', '길'): 2, ('영등포구', '계획'): 2, ('영등포구', '시급하다'): 2, ('아이', '어린이'): 2, ('무섭다', '쾌적하다'): 2, ('부분', '생각'): 2, ('공원', '확충'): 2, ('영등포구', '외국인'): 1, ('아파트', '단지'): 1, ('문제점', '실정'): 1, ('거부', '좋다'): 1, ('때', '이사'): 1, ('생활수준', '좋다'): 1, ('확충', '문래동'): 1, ('규모', '독일인'): 1, ('고령화', '면'): 1, ('거주', '독일인'): 1, ('동시', '많다'): 1, ('곳', '서울시'): 1, ('공간', '조경'): 1, ('임대', '후'): 1, ('좋다', '카페'): 1, ('임대', '해결'): 1, ('확충', '강당'): 1, ('매체', '협박'): 1, ('좁다', '이전'): 1, ('어떻다', '불편'): 1, ('생각', '변화'): 1, ('마을버스', '없다'): 1, ('노숙자', '시급하다'): 1, ('때', '작년'): 1, ('많다', '의료'): 1, ('군인', '때'): 1, ('영등포역', '무섭다'): 1, ('주민', '어떻다'): 1, ('책', '실정'): 1, ('신길동', '골목'): 1, ('공간', '아파트'): 1, ('해결', '근처'): 1, ('계획', '건너'): 1, ('규격', '버스'): 1, ('모델링', '도로'): 1, ('영등포구', '면'): 1, ('문화', '조성'): 1, ('동시', '도서관'): 1, ('카페나', '어르신'): 1, ('지역', '거리'): 1, ('층간소음', '근본'): 1, ('고령화', '대문'): 1, ('노숙자', '사창가'): 1, ('재건축', '초래'): 1, ('노현', '시설'): 1, ('아이', '공간'): 1, ('곳', '카페'): 1, ('문제', '고가도로'): 1, ('마을', '전국'): 1, ('즐겁다', '집'): 1, ('입장료', '영등포'): 1, ('방', '매점'): 1, ('요즘', '이사'): 1, ('비싸다', '실정') ...

# %%
#탐색용. 삭제가능

# print(word_cooc_mat.items())
for a,b in word_cooc_mat.items():
    print(a,b)
    break
# print(word_cooc_mat)
# Out:
# ('영등포구', '외국인') 1

# %%
# 단어관계 행렬  counter 형태 --> 리스트 내 튜플 형태로 수정 --> 정렬하기

word_coocs=[]
for words, count in word_cooc_mat.items():
    word_coocs.append((words[0],words[1],count))
# print(word_coocs)    
        
sorted_word_coocs = sorted(word_coocs, key=lambda x: x[2], reverse=True)   # 정렬하기
print(sorted_word_coocs)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
#그래프 그리기
import networkx as nx
import matplotlib.pyplot as plt

# %%
#탐색용. 삭제가능

sorted_word_coocs[:40]

# %%
G= nx.Graph()

for word1, word2, count in sorted_word_coocs[:100]:    #상위 n개로만 그림 그리기
    G.add_edge(word1, word2, weight=count)
    
T = nx.minimum_spanning_tree(G)

# %%
# 그래프 그리기

import sys

nodes = nx.nodes(T)
degrees = nx.degree(T)

node_size = []

for node in nodes:
    ns = degrees[node]*100
    
    node_size.append(ns)
    
if sys.platform in ["win32", "win64"]:
    font_name = "malgun gothic"
elif sys.platform == "darwin":
    fornt_name = "AppleGothic"
    
    
# plt.figure(figsize=(30,20))    
nx.draw(T,
       pos=nx.fruchterman_reingold_layout(G, k=0.5),
       node_size=node_size,
       node_color="#FFE27F",
       font_family=font_name,
       label_pos=1, #0=head, 0.5=center, 1=tail
        with_labels=True,
        font_size=10 )
plt.savefig("./data_구청장/명사만_관계상위100.png")
plt.axis("off")

plt.show()
# Out:
# C:\Users\namso_000\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\namso_000\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\namso_000\Anaconda3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\namso_000\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %%
len(sorted_word_coocs_word)

# %%
# 중요단어들과 관계된 SNA 그리기

# WORDS_IMPORTANT = words_most_onlyword[:20]   #중요단어 선택시활용
WORDS_IMPORTANT = words_most_onlyword[:20]     #빈도수 상위 20개 단어들로 한정

word_coocs_word=[]
for words, count in word_cooc_mat.items():
    if words[0] in WORDS_IMPORTANT or words[1] in WORDS_IMPORTANT:
        word_coocs_word.append((words[0],words[1],count))
# print(word_coocs)    
        
sorted_word_coocs_word = sorted(word_coocs_word, key=lambda x: x[2], reverse=True)   # 정렬하기
# print(sorted_word_coocs_word)


G_word= nx.Graph()


# for word1, word2, count in sorted_word_coocs_word[:int(len(sorted_word_coocs_word)*0.005)]:    #상위 n개로만 그림 그리기
for word1, word2, count in sorted_word_coocs_word[:30]:    #상위 n개로만 그림 그리기
    G_word.add_edge(word1, word2, weight=count)

T_word = nx.minimum_spanning_tree(G_word)

# %%
import sys

nodes = nx.nodes(T)
degrees = nx.degree(T)

node_size = []

for node in nodes:
    ns = degrees[node]*200
    
    node_size.append(ns)
    
if sys.platform in ["win32", "win64"]:
    font_name = "malgun gothic"
elif sys.platform == "darwin":
    fornt_name = "AppleGothic"
    
    
# plt.figure(figsize=(40,30))    
nx.draw(T_word,
       pos=nx.fruchterman_reingold_layout(G_word, k=0.5),
       node_size=node_size,
       node_color="#FFE27F",
       font_family=font_name,
       label_pos=0, #0=head, 0.5=center, 1=tail
        with_labels=True,
        font_size=10 )
plt.savefig("./data/영등포_중요단어30_관계상위20_단어제외.png")
plt.axis("off")

plt.show()

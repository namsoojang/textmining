# %%
from konlpy.tag import Komoran

# %%
#데이터 불러오기.  한줄에 댓글 하나 → 리스트로 댓글별 저장
INPUT_FILE = './data/토론샘플.txt'

datas=[]
with open(INPUT_FILE, "r") as input_file:
    for line in input_file:
        if len(line) > 3:      # 줄간격 및 공백은 삭제
#             print(len(line))
            datas.append(line.strip()[3:])
#     data=input_file.read()

print(datas)
# Out:
# ['안녕하세요 저는 대방동 군인 아파트에 살고 있는 임지연이라고 합니다. 저는 계룡시에 살다가 작년에 대방동으로 이사 왔는데요 두 아이의 엄마인데 유치원에 아이들을 보내는데 유치원 선생님들의 교육 수준과 인성에 대해 많이 실망스러웠습니다. 계룡시나 구미에서 아이들을 교육할 때는 그런 생각 안했었는데 유독 영등포구에서는 유치원 선생님들에 대한 부분에 있어 많이 부족하다는 생각이 들었습니다.', '유치원만의 문제는 아닌 거 같습니다. 요즘에는 학군 좋은 지역으로 이사까지 가는 실정인데요. 우리 영등포구도 우수교사확보 등을 통한 명문 초중고육성을 위해 우리가 학군을 점점 만들어 가야하지 않을까? 하는 그런 바람을 가져봅니다.', '전 여의도에서 직장을 다니기 위해 신길동으로 이사를 오게 되었습니다. 여의도는 아파트 단지나 골목에 주차를 해 놓은 차가 별로 없는데 신길동은 유난히 골목에 삐뚤빼뚤 주차해 놓은 차들이 많아 많은 불편을 겪고 있습니다. 차가 많다면 공용주차장을 무료로 하거나 아니면 주차공간을 규격화해서 깨끗한 주차공간을 우리가 한번 만들어 보면 어떨까? 하는 생각을 해 보게 되었습니다.', '골목은 주차문제뿐 아니라 새마을운동이라도 다시 해야 할 정도로 골목길 정리와 깨끗한 환경 조성이 시급한 거 같습니다. 골목길도 자신의 집이라고 생각한다면 쓰레기도 안 버리고 정리도 하고 울퉁불퉁한 길도 재정비 했으면 좋겠습니다.', '저는 문래동에 사는 노현주라고 합니다. 요즘 영등포구에도 공원?녹지 시설이 많이 확충되고 있는데요. 공원?녹지 공간을 확충되더라도 그 공간이 관리가 잘 되도록 했으면 좋겠습니다. 공원과 녹지가 영등포에도 많이 생기고 있는데 가고 싶은 생각이 들지 않고 조경이라든지 쉴 공간 등이 보여지기식이 아닌 주민들이 이용할 수 있게끔 관리 조성되었으면 합니다.', '골목길 안에 CCTV 설치를 강화하고 보이도록 설치하고 밝게 등도 설치해서 골목길이 낯설고 무섭기 보다는 안전하고 쾌적한 공간이 될 수 있도록 바뀌었으면 좋겠습니다.', '모든 영등포구의 문제점들을 관에서 예산만으로 해결하려 하지 말고 주민들 자체적으로 문제점들을 공유하고 해결하려고 노력하는 방향도 보태져야 한다고 생각합니다. 청소나 쓰레기정도는 스스로 치우면 어떨지....', '아~ 영등포역에 11시만 되면 노숙자분들이 많이 계시는데요. 지저분하고 냄새나고 롯데시네마에서 영화보고 나오면 무섭고 지나오기가 너무 불쾌할 정도입니다. 신도림역처럼 쾌적한 환경을 만들었으면 좋겠습니다.', '저는 도림동에서 생활한지 70년이
자리 문제도 동시에 해결되었으면 합니다.', '집도 오래되면 리모델링하듯이 영등포구 오래된 골목, 도로는 깨끗하게 리모델링하는 것이 가장 시급한 문제인거 같습니다.', '영등포구하면 유흥사창가 이미지가 아직도 있는데 이것 또한 영등포구가 가장 먼저 해결해야할 문제입니다.', '위에서 간단히 언급하신 분이 계셨는데 층간소음문제가 시급합니다. 뉴스나 언론매체에서 보면 층간소음문제의 2차적 문제로 층간간의 폭행 협박 심지어 살인까지 자행되고 있는 실정입니다. 영등포구에서도 층간소음으로 인해 신고가 많이 되고 있는 실정입니다. 이런 불길한 일을 예방하기 위해서 근본적인 문제를 해결해야할 것으로 보입니다.', '영등포구에 고가도로로 인해 소음문제와 미세먼지로 고생하고 있습니다. 고가도로를 빠른 시일에 철거해야합니다,', '로터리교통체증 개선, 버스정류장 확장 등 해결해야 할 문제가 많습니다.', '네 맞습니다. 노숙자 문제도 시급하지만 사창가도 없애야 하고 6성급 호텔을 많이 유치해야합니다.']

# %%
# 댓글별 형태소 분석하기

ma_results = []
komoran = Komoran()

for line in datas:
    ma_by_line=komoran.pos(line)
    ma_results.append(ma_by_line)

#gprint(ma_results)

# %%
#형태소분석 결과 저장하기
OUTPUT_ma_results = './data/형태소분석결과.txt'

with open(OUTPUT_ma_results, "w", encoding='utf-8') as output:
    for person in ma_results:
        for word in person:
            output.write(word[0]+',')
        output.writelines('\n')
    print('저장완료')
# Out:
# 저장완료

# %%
print(len(ma_results)) #23  23개의 언급
# Out:
# 23

# %%
print(ma_results[3])
print(type(ma_results[3]))
# Out:
# [('골목', 'NNG'), ('은', 'JX'), ('주차', 'NNG'), ('문제', 'NNG'), ('뿐', 'JX'), ('아니', 'VCN'), ('라', 'EC'), ('새마을운동', 'NNP'), ('이', 'VCP'), ('라도', 'EC'), ('다시', 'MAG'), ('하', 'VV'), ('아야', 'EC'), ('하', 'VV'), ('ㄹ', 'ETM'), ('정도', 'NNG'), ('로', 'JKB'), ('골목길', 'NNG'), ('정리', 'NNG'), ('와', 'JC'), ('깨끗', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('환경', 'NNG'), ('조성', 'NNG'), ('이', 'JKS'), ('시급', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('거', 'NNB'), ('같', 'VA'), ('습니다', 'EF'), ('.', 'SF'), ('골목길', 'NNG'), ('도', 'JX'), ('자신', 'NNG'), ('의', 'JKG'), ('집', 'NNG'), ('이', 'VCP'), ('라고', 'EC'), ('생각', 'NNG'), ('하', 'XSV'), ('ㄴ다면', 'EC'), ('쓰레기', 'NNG'), ('도', 'JX'), ('안', 'MAG'), ('버리', 'VX'), ('고', 'EC'), ('정리', 'NNG'), ('도', 'JX'), ('하', 'VV'), ('고', 'EC'), ('울퉁불퉁', 'MAG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('길', 'NNG'), ('도', 'JX'), ('재', 'XPN'), ('정비', 'NNG'), ('하', 'VV'), ('았', 'EP'), ('으면', 'EC'), ('좋', 'VA'), ('겠', 'EP'), ('습니다', 'EF'), ('.', 'SF')]
# <class 'list'>

# %%
# 댓글별 원하는 품사만 저장하기
# STOPWORD 제외하기

FILTER_IN_POSES=['NNG','NNP']   
FILTER_IN_POSES_AD1=['XR']     #어근.~하다 ex) 유쾌  
FILTER_IN_POSES_AD2=['VA']      #형용사. ~다 ex) 쉽, 어렵
#NNG 일반명사  NNP 고유명사 XR 어근 (~하다) VA 형용사(~다)
STOPWORD=['영등포','영등포구']
ma_results_selected=[]

for ma_result in ma_results:
    ma_selected=[]
    for morph_lex, morph_cat in ma_result:
        if morph_lex in STOPWORD:
            continue
        elif morph_cat in FILTER_IN_POSES:   # 일반명사이거나 고유명사일 경우 포함한다
            ma_selected.append(morph_lex)   
        elif morph_cat in FILTER_IN_POSES_AD1:
            ma_selected.append(morph_lex+'하다')
        elif morph_cat in FILTER_IN_POSES_AD2:
            ma_selected.append(morph_lex+'다')
        else:
            continue
        ma_selected=list(set(ma_selected))   #중복은 제외: 한 사람이 동일한 단어 여러번 이야기 했을 경우 제외함
    ma_results_selected.append(ma_selected)
    
print(ma_results_selected)
# Out:
# [['유치원 선생님', '부족', '유치원', '실망', '군인', '부분', '구미', '임지연', '인성', '수준', '때', '생각', '아이', '안', '이사', '안녕하세요', '계룡시', '아파트', '대방동', '엄마', '작년', '교육'], ['확보', '요즘', '지역', '같다', '실정', '유치원', '교사', '바람', '문제', '좋다', '우수', '육성', '명문', '초중고', '이사', '학군'], ['없다', '깨끗하다', '직장', '주차', '주차장', '무료', '아파트', '여의도', '신길동', '공용', '단지', '어떻다', '규격', '생각', '차', '골목', '불편', '이사', '주차공간', '많다'], ['조성', '자신', '깨끗하다', '집', '골목길', '주차', '환경', '쓰레기', '같다', '새마을운동', '정도', '생각', '문제', '정비', '좋다', '정리', '시급하다', '골목', '길'], ['녹지', '요즘', '조성', '노현', '주민', '공간', '공원', '관리', '이용', '생각', '확충', '시설', '좋다', '문래동', '조경'], ['공간', '골목길', '안전', '무섭다', '낯설다', '좋다', '설치', '강화', '밝다', '안', '쾌적하다'], ['문제점', '해결', '주민', '쓰레기', '관', '예산', '공유', '노력', '생각', '정도', '어떻다', '청소', '자체', '방향'], ['영화', '신도림역', '영등포역', '무섭다', '지저분하다', '정도', '불쾌하다', '좋다', '쾌적하다', '환경', '노숙자', '롯데시네마'], ['운영', '부분', '도림동', '생활', '거부', '낫다', '같다', '생각', '정도', '좋다', '게', '친절', '처음', '그렇다', '승차', '마을버스', '속도위반', '필요', '없다', '독점', '정리', '버스', '많다'], ['생활수준', '불균형', '전반', '지역', '아파트', '계획', '건너', '균형', '좋다', '재건축', '상점', '말씀', '커피숍', '차등', '길', '초래', '개발', '발전'], ['표시', '자전거', '노선', '같다', '도로', '규격', '좋다', '환경', '버스'], ['균일', '깨끗하다', '공장', '철재', '외관', '지역', '조금', '간판', '상가', '좁다', '생각', '어렵다', '양평', '정비', '어떻다', '변화', '시급하다', '문래동', '길', '이전'], ['마을', '곳', '크다', '서울시', '관광', '차이나타운', '규모', '문화', '거주', '명소', '대림동', '지역', '자체', '독일인', '밀집', '계획', '교류', '어떻다', '전국', '프랑스', '조성', '깨끗하다', '거리', '외국인'], ['없다', '중국', '마을', '문제점', '해결', '토론', '부족', '대림동', '마음', '자체', '주제', '판', '중국인'], ['아이', '요즘', '공간', '공원', '부족', '아파트', '놀이터', '층간소음', '생각', '학교', '문제', '좋다', '운동장', '발생', '확충', '강당', '어린이', '많다'], ['도배', '문제점', '고령화', '실정', '안전', '대문', '복지', '주거', '면', '많다', '의료', '안전장치', '낙후', '생활', '어르신', '쾌적하다'], ['동시', '마을', '곳', '발', '부족', '일자리', '즐겁다', '문제', '청소', '입장료', '생활', '놀이', '방', '키즈', '자유', '관리', '도서관', '생각', '좋다', '공인', '복지관', '소', '비싸다', '카페나', '아이', '책', '임대', '집', '해결', '후', '근처', '복지', '말씀', '어르신', '어린이', '위', '실정', '매점', '상', '동무', '카페', '마련', '장소', '많다'], ['리', '깨끗하다', '집', '모델링', '같다', '도로', '문제', '시급하다', '골목'], ['이미지', '문제', '해결', '사창가', '유흥'], ['폭행', '일', '해결', '언급', '실정', '층간소음', '살인', '매체', '층', '신고', '문제', '근본', '협박', '자행', '시급하다', '불길하다', '뉴스', '언론', '위', '예방'], ['고생', '빠르다', '미세먼지', '소음', '시일', '철거', '문제', '고가도로'], ['로터리', '해결', '교통체증', '버스정류장', '개선', '문제', '많다', '확장'], ['성급', '호텔', '유치하다', '문제', '노숙자', '시급하다', '사창가']]

# %%
#형태소분석 결과 저장하기
OUTPUT_ma_results = './data/형태소분석결과_명사어근형용사만.txt'

with open(OUTPUT_ma_results, "w", encoding='utf-8') as output:
    for person in ma_results_selected:
            for word in person:
                output.write(word+',')
            output.writelines('\n')
            
    print('저장완료')
# Out:
# 저장완료

# %%
###잠깐 딴 짓. 워드클라우드 만들기

from collections import Counter

# 빈도 높은 단어들만 가져오기
words_count=Counter()
for ma_selected in ma_results_selected:
    words_count.update(ma_selected)

# print(words_count)    
    
words_most = []
words_most_onlyword=[]
for word,count in words_count.most_common(500):
    words_most.append((word,count))
    words_most_onlyword.append(word)
    
print(words_most)
# Out:
# [('좋다', 10), ('문제', 10), ('생각', 9), ('해결', 6), ('많다', 6), ('시급하다', 5), ('깨끗하다', 5), ('같다', 5), ('지역', 4), ('부족', 4), ('아파트', 4), ('실정', 4), ('정도', 4), ('어떻다', 4), ('마을', 3), ('공간', 3), ('아이', 3), ('길', 3), ('요즘', 3), ('집', 3), ('환경', 3), ('생활', 3), ('골목', 3), ('자체', 3), ('조성', 3), ('문제점', 3), ('쾌적하다', 3), ('이사', 3), ('없다', 3), ('관리', 2), ('주민', 2), ('계획', 2), ('정비', 2), ('곳', 2), ('공원', 2), ('규격', 2), ('청소', 2), ('노숙자', 2), ('복지', 2), ('어린이', 2), ('위', 2), ('골목길', 2), ('확충', 2), ('주차', 2), ('유치원', 2), ('대림동', 2), ('층간소음', 2
차장', 1), ('밀집', 1), ('근처', 1), ('놀이터', 1), ('처음', 1), ('교사', 1), ('시설', 1), ('전국', 1), ('변화', 1), ('전반', 1), ('필요', 1), ('독점', 1), ('공장', 1), ('주거', 1), ('소음', 1), ('대방동', 1), ('노력', 1), ('어렵다', 1), ('거리', 1), ('운동장', 1), ('초래', 1), ('고가도로', 1), ('장소', 1), ('롯데시네마', 1)]

# %%
words_most_onlyword
# Out:
# ['영등포구',
#  '좋다',
#  '문제',
#  '생각',
#  '해결',
#  '많다',
#  '시급하다',
#  '깨끗하다',
#  '같다',
#  '영등포',
#  '지역',
#  '부족',
#  '아파트',
#  '실정',
#  '정도',
#  '어떻다',
#  '마을',
#  '공간',
#  '아이',
#  '길',
#  '요즘',
#  '집',
#  '환경',
#  '생활',
#  '골목',
#  '자체',
#  '조성',
#  '문제점',
#  '쾌적하다',
#  '이사',
#  '없다',
#  '관리',
#  '주민',
#  '계획',
#  '정비',
#  '곳',
#  '공원',
#  '규격',
#  '청소',
#  '노숙자',
#  '복지',
#  '어린이',
#  '위',
#  '골목길',
#  '확충',
#  '주차',
#  '유치원',
#  '안전',
#  '대림동',
#  '층간소음',
#  '문래동',
#  '안',
#  '부분',
#  '버스',
#  '도로',
#  '정리',
#  '쓰레기',
#  '말씀',
#  '어르신',
#  '사창가',
#  '무섭다',
#  '도배',
#  '유치원 선생님',
#  '공인',
#  '관광',
#  '성급',
#  '시일',
#  '관',
#  '유흥',
#  '영등포역',
#  '바람',
#  '규모',
#  '도림동',
#  '구미',
#  '놀이',
#  '여의도',
#  '중국',
#  '직장',
#  '공용',
#  '신고',
#  '좁다',
#  '매점',
#  '토론',
#  '복지관',
#  '소',
#  '밝다',
#  '버스정류장',
#  '균일',
#  '독일인',
#  '운영',
#  '교통체증',
#  '임대',
#  '무료',
#  '건너',
#  '상가',
#  '속도위반',
#  '층',
#  '생활수준',
#  '안전장치',
#  '외관',
#  '계룡시',
#  '간판',
#  '마음',
#  '균형',
#  '면',
#  '낯설다',
#  '의료',
#  '동무',
#  '우수',
#  '외국인',
#  '강당',
#  '교육',
#  '녹지',
#  '근본',
#  '확장',
#  '로터리',
#  '폭행',
#  '실망',
#  '유치하다',
#  '강화',
#  '거부',
#  '거주',
#  '이전',
#  '리',
#  '자신',
#  '명소',
#  '철재',
#  '이용',
#  '개선',
#  '이미지',
#  '비싸다',
#  '일자리',
#  '불편',
#  '낫다',
#  '후',
#  '친절',
#  '카페',
#  '철거',
#  '승차',
#  '불쾌하다',
#  '단지',
#  '낙후',
#  '마을버스',
#  '커피숍',
#  '영화',
#  '안녕하세요',
#  '자행',
#  '신길동',
#  '상',
#  '양평',
#  '재건축',
#  '차이나타운',
#  '도서관',
#  '마련',
#  '발전',
#  '예방',
#  '판',
#  '표시',
#  '노현',
#  '노선',
#  '즐겁다',
#  '군인',
#  '매체',
#  '공유',
#  '지저분하다',
#  '발생',
#  '차',
#  '뉴스',
#  '주제',
#  '방',
#  '임지연',
#  '신도림역',
#  '때',
#  '상점',
#  '초중고',
#  '방향',
#  '학군',
#  '확보',
#  '불균형',
#  '미세먼지',
#  '조금',
#  '자전거',
#  '교류',
#  '그렇다',
#  '학교',
#  '육성',
#  '차등',
#  '조경',
#  '고령화',
#  '모델링',
#  '예산',
#  '대문',
#  '살인',
#  '새마을운동',
#  '엄마',
#  '작년',
#  '주차공간',
#  '동시',
#  '언급',
#  '일',
#  '서울시',
#  '발',
#  '설치',
#  '책',
#  '크다',
#  '입장료',
#  '문화',
#  '불길하다',
#  '명문',
#  '언론',
#  '개발',
#  '키즈',
#  '자유',
#  '인성',
#  '협박',
#  '호텔',
#  '수준',
#  '프랑스',
#  '게',
#  '카페나',
#  '고생',
#  '중국인',
#  '빠르다',
#  '주차장',
#  '밀집',
#  '근처',
#  '놀이터',
#  '처음',
#  '교사',
#  '시설',
#  '전국',
#  '변화',
#  '전반',
#  '필요',
#  '독점',
#  '공장',
#  '주거',
#  '소음',
#  '대방동',
#  '노력',
#  '어렵다',
#  '거리',
#  '운동장',
#  '초래',
#  '고가도로',
#  '장소',
#  '롯데시네마']

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from wordcloud import WordCloud

tmp = dict(words_most)
wordcloud=WordCloud(font_path="c:/Windows/Fonts/malgun.ttf", relative_scaling=0.3, 
                    background_color="white", max_words=50,
                   font_step=10).generate_from_frequencies(tmp)
plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('./data/wordcloud(white)_불필요단어제외.png')

# %%
# 벡터행렬 생성하기

from collections import Counter

# %%
# 취소
# 단어 관계 행렬 만들기  1씩 깔아놓기

from itertools import combinations

word_cooc_mat=Counter()

for word1, word2 in combinations(words_most_onlyword,2):
    word_cooc_mat[(word1,word2)]+=1

# %%
print(word_cooc_mat)
# Out:
# Counter({('문제점', '독일인'): 1, ('도서관', '언론'): 1, ('조금', '근처'): 1, ('도로', '불균형'): 1, ('계획', '도로'): 1, ('폭행', '간판'): 1, ('공원', '중국인'): 1, ('안녕하세요', '동시'): 1, ('일', '대방동'): 1, ('방', '독점'): 1, ('시급하다', '건너'): 1, ('자전거', '교사'): 1, ('유흥', '발생'): 1, ('규모', '소음'): 1, ('공용', '철거'): 1, ('후', '뉴스'): 1, ('신길동', '설치'): 1, ('좁다', '임지연'): 1, ('이미지', '그렇다'): 1, ('발전', '불길하다'): 1, ('자체', '노현'): 1, ('안전장치', '밀집'): 1, ('교통체증', '살인'): 1, ('유치원 선생님', '마련'): 1, ('강당', '후'): 1, ('없다', '유치원'): 1, ('안', '비싸다'): 1, ('예산', '입장료'): 1, ('지역', '새마을운동'): 1, ('생활', '주차장'): 1, ('주민', '낙후'): 1, ('유치원 선생님', '중국인'): 1, ('계획', '새마을운동'): 1, ('공인', '예방'): 1, ('구미', '이용'): 1, ('유치원', '계룡시'): 1, ('조성', '소음'): 1, ('문제', '낙후'): 1, ('정비', '확충'): 1, ('실정', '설치'): 1, ('안전장치', '중국인'): 1, ('마을', '문래동'): 1
일'): 1, ('관', '후'): 1, ('상점', '협박'): 1, ('매체', '개발'): 1, ('방향', '협박'): 1, ('낙후', '일'): 1, ('거부', '자전거'): 1, ('계획', '매점'): 1, ('비싸다', '마을버스'): 1, ('어린이', '놀이'): 1, ('구미', '층'): 1, ('지역', '불길하다'): 1, ('고령화', '주거'): 1, ('어린이', '언급'): 1, ('방', '자전거'): 1, ('없다', '시설'): 1, ('낙후', '학군'): 1, ('신길동', '노현'): 1, ('임대', '근처'): 1, ('구미', '교통체증'): 1, ('초중고', '살인'): 1, ('마을', '근처'): 1, ('속도위반', '즐겁다'): 1, ('지역', '곳'): 1, ('친절', '차등'): 1, ('층', '주차장'): 1, ('마을버스', '군인'): 1, ('버스정류장', '카페나'): 1, ('표시', '책'): 1, ('재건축', '엄마'): 1, ('관리', '카페나'): 1, ('운영', '안녕하세요'): 1, ('서울시', '교사'): 1, ('어떻다', '균일'): 1, ('인성', '수준'): 1, ('균일', '카페나'): 1, ('안', '소음'): 1, ('실정', '이용'): 1, ('폭행', '개발'): 1, ('도서관', '변화'): 1, ('아파트', '복지관'): 1, ('개선', '공장'): 1, ('좁다', '인성'): 1, ('길', '층간소음'): 1, ('때', '프랑스'): 1, ('아파트', '생활'): 1, ('관', '군인'): 1, ('주차', '관광'): 1, ('마을버스', '자전거'): 1, ('신길동', '모델링'): 1, ('환경', '주차공간'): 1, ('밝다', '새마을운동'): 1, ('육성', '언급'): 1, ('요즘', '단지'): 1, ('층', '명문'): 1, ('복지', '발생'): 1, ('버스', '호텔'): 1, ('문제점', '예방'): 1, ('공유', '고가도로'): 1, ('카페', '크다'): 1, ('육성', '언론'): 1, ('교류', '대문'): 1, ('안', '발전'): 1, ('노력', '거리'): 1, ('시급하다', '공인'): 1, ('깨끗하다', '계룡시'): 1, ('버스', '엄마'): 1, ('전반', '어렵다'): 1, ('골목길', '명문'): 1, ('상점', '빠르다'): 1, ('매점', '거부'): 1, ('없다', '곳'): 1, ('어린이', '엄마'): 1, ('자신', '재건축'): 1, ('안전', '새마을운동'): 1, ('설치', '수준'): 1, ('층간소음', '낯설다'): 1, ('자체',  ...

# %%
# 단어 관계 행렬 쓰기 
from collections import Counter
from itertools import combinations

word_cooc_mat=Counter()

for line in ma_results_selected:
    for word1, word2 in combinations(line,2):
#         print(word1, word2)
        word_cooc_mat[(word1,word2)]+=1

# %%
print(word_cooc_mat)
# Out:
# Counter({('영등포구', '문제'): 5, ('생각', '좋다'): 5, ('문제', '시급하다'): 4, ('문제', '좋다'): 4, ('영등포구', '해결'): 4, ('같다', '좋다'): 4, ('영등포구', '실정'): 4, ('생각', '많다'): 4, ('생각', '영등포'): 4, ('깨끗하다', '골목'): 3, ('같다', '문제'): 3, ('영등포구', '좋다'): 3, ('요즘', '좋다'): 3, ('영등포', '좋다'): 3, ('해결', '문제'): 3, ('좋다', '많다'): 3, ('부족', '영등포'): 3, ('문제', '많다'): 3, ('영등포구',
    break
# print(word_cooc_mat)
# Out:
# ('영등포구', '외국인') 1

# %%
# 단어관계 행렬  counter 형태 --> 리스트 내 튜플 형태로 수정 --> 정렬하기

word_coocs=[]
for words, count in word_cooc_mat.items():
    word_coocs.append((words[0],words[1],count))
# print(word_coocs)    
        
sorted_word_coocs = sorted(word_coocs, key=lambda x: x[2], reverse=True)   # 정렬하기
print(sorted_word_coocs)
# Out:
# [('생각', '좋다', 5), ('문제', '좋다', 4), ('같다', '좋다', 4), ('생각', '많다', 4), ('문제', '시급하다', 4), ('깨끗하다', '골목', 3), ('같다', '문제', 3), ('요즘', '좋다', 3), ('좋다', '많다', 3), ('문제', '많다', 3), ('깨끗하다', '생각', 3), ('공간', '좋다', 3), ('깨끗하다', '시급하다', 3), ('부족', '생각', 3), ('정도', '좋다', 3), ('문제점', '해결', 2), ('정비', '길', 2), ('생각', '이사', 2), ('깨끗하다', '어떻다', 2), ('조성', '좋다', 2), ('부족', '좋다', 2), ('주차', '생각', 2), ('요즘', '생각', 2), ('집', '시급하다', 2), ('생각', '확충', 2), ('요즘', '확충', 2), ('지역', '길', 2), ('주차', '골목', 2), ('생각', '정리', 2), ('생활', '생각', 2), ('같다', '도로', 2), ('문제', '위', 2), ('해결', '실정', 2), ('좋다', '쾌적하다', 2), ('부족', '많다', 2), ('부족', '어린이', 2), ('지역', '어떻다', 2), ('시급하다', '골목', 2), ('깨끗하다', '집', 2), ('문제', '사창가', 2), ('생각', '정도', 2), ('좋다', '버스', 2), ('생각', '아이', 2), ('정도', '정리', 2), ('마을', '대림동', 2), ('해결', '문제', 2), ('무섭다', '좋다', 2), ('지역', '계획', 2), ('좋다', '길', 2), ('관리', '생각', 2), ('생각', '시급하다', 2), ('좋다', '정리', 2), ('같다', '버스', 2), ('관리', '좋다', 2), ('조성', '생각', 2), ('부족', '아파트', 2), ('공간', '공원', 2), ('아이', '아파트', 2), ('공간', '생각', 2), ('안전', '쾌적하다', 2), ('좋다', '환경', 2), ('아파트', '좋다', 2), ('생각', '어린이', 2), ('문제', '해결', 2), ('생활', '많다', 2), ('깨끗하다', '주차', 2), ('실정', '문제', 2), ('부족', '문제', 2), ('좋다', '말씀', 2), ('해결', '많다', 2), ('복지', '많다', 2), ('같다', '정도', 2), ('부족', '아이', 2), ('좋다', '어린이', 2), ('생각', '어떻다', 2), ('문제', '골목', 2), ('생각', '길', 2), ('시급하다', '길', 2), ('같다', '정리', 2), ('깨끗하다', '문제', 2), ('생각', '골목', 2), ('골목길', '좋다', 2), ('공원', '좋다', 2), ('생각', '정비', 2), ('유치원', '이사', 2), ('같다', '골목', 2), ('주민', '생각', 2), ('같다', '생각', 2), ('없다', '많다', 2), ('조성', '깨끗하다', 2), ('쓰레기', '정도', 2), ('마을', '부족', 2), ('생각', '문래동', 2), ('마을', '곳', 2), ('해결', '자체', 2), ('깨끗하다', '같다', 2), ('실정', '많다', 2), ('아파트', '많다', 2), ('정비', '시급하다', 2), ('요즘', '공원', 2), ('요즘', '공간', 2), ('깨끗하다', '정비', 2), ('층간소음', '문제', 2), ('공간', '확충', 2), ('집', '문제', 2), ('지역', '좋다', 2), ('공원', '생각', 2), ('집', '같다', 2), ('아파트', '생각', 2), ('같다', '시급하다', 2), ('요즘', '문제', 2), ('생각', '문제', 2), ('해결', '위', 2), ('문제', '어린이', 2), ('아이', '많다', 2), ('쓰레기', '생각', 2), ('문제점', '자체', 2), ('집', '골목', 2), ('생활', '좋다', 2), ('어린이', '많다', 2), ('복지', '어르신', 2), ('마을', '자체', 2), ('마을', '해결', 2), ('생활', '어르신', 2), ('대림동', '자체', 2), ('깨끗하다', '길', 2), ('아이', '어린이', 2), ('무섭다', '쾌적하다', 2), ('부분', '생각', 2), ('공원', '확충', 2), ('아파트', '단지', 1), ('문제점', '실정', 1), ('거부', '좋다', 1), ('때', '이사', 1), ('생활수준', '좋다', 1), ('확충', '문래동', 1), ('규모', '독일인', 1), ('고령화', '면', 1), ('거주', '독일인', 1), ('동시', '많다', 1), ('곳', '서울시', 1), ('공간', '조경', 1), ('임대', '후', 1), ('좋다', '카페', 1), ('임대', '해결', 1), ('확충', '강당', 1), ('좁다', '이전', 1), ('어떻다', '불편', 1), ('쓰레기', '청소', 1), ('생각', '변화', 1), ('마을버스', '없다', 1), ('노숙자', '시급하다', 1), ('때', '작년', 1), ('많다', '의료', 1), ('군인', '때', 1), ('영등포역', '무섭다', 1), ('주민', '어떻다', 1), ('책', '실정', 1), ('신길동', '골목', 1), ('공간', '아파트', 1), ('해결', '근처', 1), ('계획', '건너', 1), ('규격', '버스', 1), ('모델링', '도로', 1), ('좋다', '이사', 1), ('문화', '조성', 1), ('동시', '도서관', 1), ('지역', '거리', 1), ('층간소음', '근본', 1), ('고령화', '대문', 1), ('노숙자', '사창가', 1), ('재건축', '초래', 1), ('노현', '시설', 1), ('아이', '공간', 1), ('곳', '카페', 1), ('문제', '고가도로', 1), ('마을', '전국', 1), ('즐겁다', '집', 1), ('요즘', '이사', 1), ('비싸다', '실정', 1), ('놀이터', '생각', 1), ('관', '어떻다', 1), ('면', '의료', 1), ('곳', '깨끗하다', 1), ('영등포역', '정도', 1), ('문화', '명소', 1), ('크다', '어떻다', 1), ('주차장', '많다', 1), ('집', '매점', 1), ('해결', '신고', 1), ('해결', '층', 1), ('안녕하세요', '작년', 1), ('길', '발전', 1), ('말씀', '발전', 1), ('운영', '생활', 1), ('매점', '장소', 1), ('해결', '주제', 1), ('낯설다', '좋다', 1), ('공원', '강당', 1), ('놀이', '실정', 1), ('규모', '밀집', 1), ('입장료', '소', 1), ('해결', '교통체증', 1), ('아파트', '차', 1), ('마을', '동무', 1), ('문제점', '어떻다', 1), ('아파트', '발전', 1), ('좋다', '복지', 1), ('동시', '소', 1), ('조금', '좁다', 1), ('안전', '좋다', 1), ('재건축', '개발', 1), ('관광', '밀집', 1), ('리', '골목', 1), ('미세먼지', '철거', 1), ('전반', '길', 1), ('장소', '많다', 1), ('키즈', '복지관', 1), ('생각', '위', 1), ('놀이', '매점', 1), ('입장료', '생각', 1), ('정비', '좋다', 1), ('후', '동무', 1), ('어르신', '실정', 1), ('깨끗하다', '환경', 1), ('서울시', '깨끗하다', 1), ('노력', '청소', 1), ('고령화', '생활', 1), ('균형', '좋다', 1), ('전 ...

# %%
#그래프 그리기
import networkx as nx
import matplotlib.pyplot as plt

# %%
#탐색용. 삭제가능

sorted_word_coocs[:40]

# %%
G= nx.Graph()

for word1, word2, count in sorted_word_coocs[:30]:    #상위 n개로만 그림 그리기
    G.add_edge(word1, word2, weight=count)
    
T = nx.minimum_spanning_tree(G)

# %%
# 그래프 그리기

import sys

nodes = nx.nodes(T)
degrees = nx.degree(T)

node_size = []

for node in nodes:
    ns = degrees[node]*100
    
    node_size.append(ns)
    
if sys.platform in ["win32", "win64"]:
    font_name = "malgun gothic"
elif sys.platform == "darwin":
    fornt_name = "AppleGothic"
    
    
# plt.figure(figsize=(30,20))    
nx.draw(T,
       pos=nx.fruchterman_reingold_layout(G, k=0.5),
       node_size=node_size,
       node_color="#FFE27F",
       font_family=font_name,
       label_pos=1, #0=head, 0.5=center, 1=tail
        with_labels=True,
        font_size=10 )
plt.savefig("./data/영등포_관계상위30_단어제외.png")
plt.axis("off")

plt.show()

# %%
len(sorted_word_coocs_word)

# %%
# 중요단어들과 관계된 SNA 그리기

# WORDS_IMPORTANT = words_most_onlyword[:20]   #중요단어 선택시활용
WORDS_IMPORTANT = words_most_onlyword[:20]     #빈도수 상위 20개 단어들로 한정

word_coocs_word=[]
for words, count in word_cooc_mat.items():
    if words[0] in WORDS_IMPORTANT or words[1] in WORDS_IMPORTANT:
        word_coocs_word.append((words[0],words[1],count))
# print(word_coocs)    
        
sorted_word_coocs_word = sorted(word_coocs_word, key=lambda x: x[2], reverse=True)   # 정렬하기
# print(sorted_word_coocs_word)


G_word= nx.Graph()


# for word1, word2, count in sorted_word_coocs_word[:int(len(sorted_word_coocs_word)*0.005)]:    #상위 n개로만 그림 그리기
for word1, word2, count in sorted_word_coocs_word[:30]:    #상위 n개로만 그림 그리기
    G_word.add_edge(word1, word2, weight=count)

T_word = nx.minimum_spanning_tree(G_word)

# %%
import sys

nodes = nx.nodes(T)
degrees = nx.degree(T)

node_size = []

for node in nodes:
    ns = degrees[node]*200
    
    node_size.append(ns)
    
if sys.platform in ["win32", "win64"]:
    font_name = "malgun gothic"
elif sys.platform == "darwin":
    fornt_name = "AppleGothic"
    
    
# plt.figure(figsize=(40,30))    
nx.draw(T_word,
       pos=nx.fruchterman_reingold_layout(G_word, k=0.5),
       node_size=node_size,
       node_color="#FFE27F",
       font_family=font_name,
       label_pos=0, #0=head, 0.5=center, 1=tail
        with_labels=True,
        font_size=10 )
plt.savefig("./data/영등포_중요단어30_관계상위20_단어제외.png")
plt.axis("off")

plt.show()

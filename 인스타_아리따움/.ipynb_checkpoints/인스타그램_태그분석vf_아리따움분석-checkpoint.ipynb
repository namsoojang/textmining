# %%
from selenium import webdriver
import time
import random
from bs4 import BeautifulSoup
import re
from datetime import datetime
import json
import pandas as pd

# %%
fname = './data/검색결과_아리따움_3000_12131056.csv'
datas = pd.read_csv(fname)

# %% [markdown]
# ## 검색결과 불러오기

# %%
print(len(datas))
# Out:
# 2999

# %%
datas.head()
# Out:
#             ﻿writer                                            article  \
# 0   totokodeog_motd  오늘의 립-#아리따움 #젤리바 #멜팅슈#토니모리 #립톤겟잇틴트 #레드핫#넘버7 #하...
# 1  aritaum_official  [로맨틱 홀리데이_LET IT SNOW]아직도 겨울네일 뭐할지 고민중이시라구요?-차...
# 2       fascinate_s  호잇 새로운 아이메이크업영상이!!원브랜드꿀조합 담아봤으니 불토! 불일!에 도전해봐요...
# 3    hanyulofficial  입술이 갈라지기 쉬운 겨울,#자연감성 으로 향기롭고 촉촉하게 케어하세요. #자연을닮...
# 4       betweendots  Do you wait for your Black Friday and pre-Blac...
#
#     likes  replys_count                                             replys  \
# 0    4310             8  (1, 'themonthapril', '@aoibhok'), (2, 'discoso...
# 1     537             1                                                '0'
# 2  526402            55  (1, 'youngju42835', '영상 올라오자마자 바로 봣습니당~'), (2,...
# 3     370             2  (1, 'ilovenail.wonju', '잘 보고 갑니다✌'), (2, 'stto...
# 4     202            11  (1, 'properrosy', 'I still have like 4 to come...
#
#            datetime                                                img  \
# 0  2017-12-09 13:04  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 1  2017-12-13 01:34  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2  2017-12-01 10:40  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 3  2017-12-12 02:34  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 4  2017-12-12 19:33  https://scontent-icn1-1.cdninstagram.com/t51.2...
#
#                                                 tags
# 0  '#아리따움', '#젤리바', '#멜팅슈', '#토니모리', '#립톤겟잇틴트', '...
# 1  '#크리스마스네일', '#연말네일', '#고요한밤', '#로맨틱홀리데이', '#셀프...
# 2  '#뷰티유튜버', '#아리따움', '#색조합', '#아이메이크업', '#eyemak...
# 3  '#자연감성', '#자연을닮은립밤_', '#한율립밤', '#한율자연템', '#립밤'...
# 4  '#aritaum', '#kbeauty', '#abcommunity', '#rasi...

# %%
datas['likes'].fillna(0)
# Out:
# 0         4310
# 1          537
# 2       526402
# 3          370
# 4          202
# 5         1909
# 6          677
# 7          167
# 8          689
# 9           18
# 10           3
# 11          26
# 12          10
# 13          39
# 14          35
# 15          13
# 16         230
# 17          15
# 18          31
# 19          37
# 20          18
# 21           1
# 22          16
# 23          34
# 24          33
# 25           4
# 26          33
# 27          42
# 28          30
# 29          18
#          ...
# 2969        80
# 2970       179
# 2971        32
# 2972        59
# 2973       195
# 2974       147
# 2975        29
# 2976        42
# 2977        34
# 2978        11
# 2979        54
# 2980        29
# 2981        11
# 2982       303
# 2983       362
# 2984        49
# 2985       100
# 2986        38
# 2987        55
# 2988        38
# 2989       145
# 2990        11
# 2991        24
# 2992        11
# 2993        18
# 2994       130
# 2995        17
# 2996        13
# 2997         3
# 2998         6
# Name: likes, dtype: int64

# %%
datas.dtypes
# Out:
# ﻿writer         object
# article         object
# likes            int64
# replys_count     int64
# replys          object
# datetime        object
# img             object
# tags            object
# dtype: object

# %% [markdown]
# # 분석하기

# %% [markdown]
# ### 시계열 분석하기

# %%
def insta_trends_analyser(datas):
    # datas: insta 크롤 결과 pandas 자료형 형태
    datas['day'] = [date[:10] for date in datas['datetime']]    # #월/일 값만 추가  2017-11-25형태
    
    trends = pd.DataFrame()
    trends['article'] = datas.groupby(datas['day'])['article'].count()  #  일자별 인스타 포스팅수
    trends['replies'] = datas.groupby(datas['day'])['replys_count'].sum() # 일자별 댓글 작성수
    trends['likes'] = datas.groupby(datas['day'])['likes'].sum()     # 일자별 좋아요 수
    trends['sum'] = trends.replies + trends.article + trends.likes
    
    return trends

# %%
insta_trends = insta_trends_analyser(datas)

# %%
insta_trends.head()
# Out:
#             article  replies  likes   sum
# day
# 2017-11-10       12       28    471   511
# 2017-11-11       42      247   3456  3745
# 2017-11-12       53      385   6357  6795
# 2017-11-13       49      268   3092  3409
# 2017-11-14       45      291   4752  5088

# %%
# %matplotlib inline
# trends.plot(y = ['article','replys','sum'], ylim=(0,trends['sum'].max()))
insta_trends.plot(y = ['article','replies','likes','sum'])
insta_trends.plot(y = ['article','replies'])

# %% [markdown]
# ### 태그 분석하기: 빈도수

# %%
# 태그 빈도수 계산하기

from collections import Counter

def tag_counter(tag_lists):
    # 인스타 태그 수집결과를 입력하면, 태그 빈도수 카운트가 높은 순으로 보여줌  
    # tag_lists = ["'#라인1태그1'",    "'라인2태그1', '라인2태그2', '라인2태그3'" ] 형식
    
    tag_counts = Counter()
    for tags in tag_lists:
        try: tag_counts.update(tags.replace("'",'').replace(' ','').strip().split(','),)
        except: continue
    tag_counts = tag_counts.most_common()  # 정열하기
    
    return tag_counts

# %%
# 상위 태그 그림그리기

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

def tag_counts_chart(tag_counts, n):
    # matplotlib 한글 사용하기
    font_location = 'c:/Windows/fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=font_location).get_name()
    rc('font',family=font_name)
    
    labels, values = [],[]
    for tags in reversed(tag_counts[:n]):   # 가로 그래프일 경우에는 reversed 로 순서 변경해준다
        label, value = tags
        labels.append(label)
        values.append(value)

    indexes = np.arange(len(labels))
    width = 1
    fig = plt.figure(figsize = (8,5))
    plt.barh(indexes, values, width)  # 수평 바 그래프
    plt.yticks(indexes + width * 0.5, labels, rotation='0')

    # 세로그래프일 경우
    # plt.bar(indexes, values, width)
    # plt.xticks(indexes + width * 0.5, labels, rotation='90') 
    plt.show()

# %%
# 참고) 바차트 그리기
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# matplotlib 한글 사용하기
font_location = 'c:/Windows/fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)

labels, values = [],[]

for tags in tag_counts[:30]:   # 가로 그래프일 경우에는 reversed 로 순서 변경해준다
    label, value = tags
    labels.append(label)
    values.append(value)

indexes = np.arange(len(labels))
width = 1
fig = plt.figure(figsize = (8,5))
plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels, rotation='90')
plt.show()

# %% [markdown]
# ### tag분석: 워드클라우드

# %%
# STOPWORD 제외
def tag_counts_sellector(tag_counts, STOP):
    # STOP 단어를 제외하여  리스트 형태로 출력함(카운터 --> 리스트 형태 변경됨)
    tag_counts_e = []
    for word, count in tag_counts:
        if word not in STOP:
            tag_counts_e.append((word,count))
    return tag_counts_e

# %%
# 워드클라우드 그리기

# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

def tag_wordcloud(tag_counts, word_num):
    tmp = dict(tag_counts[:word_num])
    wordcloud=WordCloud(font_path="c:/Windows/Fonts/malgun.ttf", relative_scaling=0.5, 
                        background_color="white", max_words=100).generate_from_frequencies(tmp)    #font_step=5
    plt.figure(figsize=(8,6))
    plt.imshow(wordcloud)
    plt.axis('off')

# %%
# 태그 빈도 분석1: 집계

tag_lists = datas['tags'].tolist() # 인스타 크롤링 결과 중 태그를 가져온다
tag_counts = tag_counter(tag_lists)  # 태그 카운트 집계한다
tag_counts_chart(tag_counts, 30)    # 시각화1) 상위 태그 그래프로 확인함

# %%
# 태그 빈도 분석2: 정리하기
STOP = ['#아리따움','#코덕','#뷰티스타그램','#aritaum','#코덕스타그램','#뷰스타그램']

tag_counts_selected = tag_counts_sellector(tag_counts, STOP)    # 불용어 데이터 확인한다
tag_counts_chart(tag_counts_selected, 20)    # 시각화1) 상위 태그 그래프로 확인함
tag_wordcloud(tag_counts_selected,50)        # 시각화2) 워드클라우드 그리기

# %% [markdown]
# ## 2) SNA

# %%
# 단어 관계 행렬 쓰기 
from collections import Counter
from itertools import combinations

# %%
# 게시글별 태그리스트 정리한다

def tag_lists_selector(tag_lists, STOP):
    
    # 인스타 태그 검색결과 중 일부
    
    tag_lists_sel = []
    for tags in tag_lists:
        tag_sel = tags.replace("'",'').replace(' ','').split(',')
        tag_lists_sel.append(tag_sel)
    return tag_lists_sel

# %%
# 단어 관계 행렬 쓰기 
from collections import Counter
from itertools import combinations


def word_matrix(tag_lists, stop=None, must=None):
    # 매트릭스 만들기
    word_cooc_mat=Counter()
    for line in tag_lists:
        for word1, word2 in combinations(line,2):
            if stop!=None and (word1 in stop or word2 in stop): continue
            if must!=None and (word1 not in must and word2 not in must): continue
            if word1 == word2: continue  #동일한 단어간의 벡터는 계산하지 않음
            elif word_cooc_mat[(word2,word1)]>=1:word_cooc_mat[(word2,word1)]+=1
            else: word_cooc_mat[(word1,word2)]+=1    
    
    word_coocs = []
    for words, count in word_cooc_mat.items():
        word_coocs.append((words[0],words[1],count))
    
    sorted_word_coocs = sorted(word_coocs, key=lambda x: x[2], reverse=True)   # 정렬하기
    
    return sorted_word_coocs

# %%
#그래프 그리기
import networkx as nx
import matplotlib.pyplot as plt
import sys

def word_sna_graph(word_matrix, n, fname=None):
    G= nx.Graph()
    for word1, word2, count in word_matrix[:n]:    #상위 n개로만 그림 그리기
        G.add_edge(word1, word2, weight=count)
    T = nx.minimum_spanning_tree(G)
    nodes = nx.nodes(T)
    degrees = nx.degree(T)
    node_size = []

    for node in nodes:
        ns = degrees[node]*200
        node_size.append(ns)

    if sys.platform in ["win32", "win64"]: font_name = "malgun gothic"
    elif sys.platform == "darwin": fornt_name = "AppleGothic"
    plt.figure(figsize=(16,13))    
    nx.draw(T,
           pos=nx.fruchterman_reingold_layout(G, k=0.5),
           node_size=node_size,
           node_color="#FFE27F",
           font_family=font_name,
           label_pos=0, #0=head, 0.5=center, 1=tail
            with_labels=True,
            font_size=10 )
    if fname!=None: 
        plt.savefig(fname)
        print('{}에 저장하였습니다'.format(fname))
    plt.axis("off")

    plt.show()

# %%
STOP = ['#아리따움','#코덕','#뷰티스타그램','#aritaum','#코덕스타그램','#뷰스타그램','#']
# must = ['#강아지습진', '#강아지샴푸','#강아지비누']
must = None

tag_lists = datas['tags'].dropna().tolist() # 인스타 크롤링 결과 중 태그를 가져온다
tag_lists_selected = tag_lists_selector(tag_lists,STOP)
word_cooc = word_matrix(tag_lists_selected, stop=STOP, must=must)
print(word_cooc[:20])

fname = './data/아리따움v1_100'
word_sna_graph(word_cooc,100,fname) #저장할경우

# word_sna_graph(word_cooc,200)
# Out:
# [('#에뛰드하우스', '#맥', 381), ('#이니스프리', '#에뛰드하우스', 381), ('#이니스프리', '#맥', 340), ('#에뛰드하우스', '#메이크업', 195), ('#이니스프리', '#메이크업', 187), ('#메이크업', '#맥', 172), ('#맥', '#루비우', 169), ('#에뛰드하우스', '#루비우', 167), ('#이니스프리', '#잭버건디', 166), ('#이니스프리', '#피오니가피어나', 166), ('#잭버건디', '#맥', 166), ('#피오니가피어나', '#맥', 166), ('#에뛰드하우스', '#피오니가피어나', 166), ('#이니스프리', '#노을지는하늘', 166), ('#잭버건디', '#에뛰드하우스', 166), ('#이니스프리', '#루비우', 166), ('#노을지는하늘', '#에뛰드하우스', 166), ('#노을지는하늘', '#맥', 166), ('#makeup', '#메이크업', 149), ('#화장품', '#메이크업', 129)]
# ./data/아리따움v1_100에 저장하였습니다

# %%
# 특정단어 트랜드 분석

# %%
check = ['#입생로랑' in str(tags) for tags in datas.tags]
datas[check]
# Out:
#                  ﻿writer                                            article  \
# 65              vnletter  #할리스#고구마라떼🍠#먹스타그램🍴#아리따움#프레시파워에센스마스크#쉐어버터#오늘의파우...
# 277              si_0326  카페☕️..#추운 #겨울 #따뜻한 #카페 #에서 #수다떨기 #아리따움 #섀도우팔레트...
# 388        twinkle.clara  #화장품아무도 #안물안궁 이지만...ㅋㅋ 제가 쓰는 메이크업 제품 몇개 소개 합니당...
# 390              yndm222  한때 지니고 다녔던아가들 😘단종되어 없는 템들도 !?#여자라면누구나#화장품#립스틱#...
# 508            ansser24_  🌺주왕주왕 립메이크업🌺립메이크업이라고 할것도 없는 그저 틴트 발색... 예전에 #아...
# 509            seonbinii  꺄 너무추어-#광주 #흔녀 #selfie #selca #daily #일상 #시험기간...
# 651             dd_ccong  ¥20171203.'ㅡ'TWO호우의일상#독서⠀⠀⠀⠀⠀⠀⠀누군가의 말 한마디가 소년에...
# 659   iwantthatredvelvet  김태랑이 내 앞머리 깜찍이라고 했어 ㅇㅅㅇ #motd #urbandecay #mid...
# 660   iwantthatredvelvet  김태랑이 내 앞머리 깜찍이라고 했어 ㅇㅅㅇ #motd #urbandecay #mid...
# 977           im_jinvely  어떤 메이크업이든 전부 소화가능하신 뚜렷한 이목구비를 가지신 고객님❤️이목구비에서 ...
# 1048          im_jinvely  승무원을 준비하고 계신 고객님❤️단아한 이미지를 살리려고 진하지않은 메이크업으로 이...
# 1251            dd_ccong  ¥20171125⠀⠀⠀⠀⠀⠀⠀'ㅡ'TWO호우의일상#이벤트⠀⠀⠀⠀⠀⠀⠀TWO호우와 함...
# 1265            dajung_o  #다정메컵🍒 #오늘의화장오늘은 깨끗한 아이메컵👀eye#바비브라운#토스트#엑셀#sl0...
# 1366         mingvvely13  #일상스타그램 #코덕 #쉐도우 #틴트스트레스받을땐 역시 돈쓰는게 최고야👌 #돈쓰는게...
# 1541           k.hm_oodt  립스티 모으는 재미~ ..#립 #립스틱 #틴트 #입생로랑 #로하셀 #아리따움 #MA...
# 1720          kano.cosme  #171118 #카노티디#오늘의화장#오늘의메이크업#motd#makeupoftheda...
# 2109              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2110              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2111              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2112              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2113              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2114              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2115              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2116              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2117              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2118              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2119              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2120              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2121              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2122              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# ...                  ...                                                ...
# 2148              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2149              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2150              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2151              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2152              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2153              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2154              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2155              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2156              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2157              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2158              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2159              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2160              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2161              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2162              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2163              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2164              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2165              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2166              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2167              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2168              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2169              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2170              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2171              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2172              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2173              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2174              ye2nny  쓰는 립 모아봤는뎈ㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋ평생써도될듯 그만사자.. 하지만 하늘아래 같은 ...
# 2803           zzanzi_jj  많이 정리했다......ㅎㅎ 아직도 샘플이 많다... 화장품 창고도 정리해야디......
# 2854      heather_n_liv_  💚#가지고있는_립제품_발색--*틴트는 T, 비교적 매트한 제품은 M, 색상명 표기가...
# 2979          minnieunni  요즘데일리.#에스티로더 #아리따움 #베네피트 #데일리 #샤넬 #어반디케이 #나스 #...
#
#       likes  replys_count                                             replys  \
# 65        9             2  (1, 'jjuninajjang', '잘봤어요~ 자주 소통나누고 지내요~✨💫'), ...
# 277      25             1                   (1, '_m___j1022', '꿀잼~~~~~또갈ㄹ래')
# 388      37             8  (1, 'so_jeong.120', 'ㅋㅋㅋ 좋은정보 감사여언니 저두클리오킬블랙쓰는...
# 390      15             4  (1, 'ziggycroz', 'Very cool!'), (2, 'yndm222',...
# 508       8             1                                                '0'
# 509      94             6  (1, 'ro_sha___', '빛나는 나를 더 빛나게 할 예쁘고 저렴한 악세서리 ...
# 651     264             1  (1, 'beauty_theqoo', "뷰티더쿠들 보시오! '뷰티더쿠'에서 뷰티 정...
# 659     115             1  (1, 'k.taerang', '김태랑입니다. 깜찍이스타일 찾아쥴래다가 인생 밑바닥...
# 660     115             1  (1, 'k.taerang', '김태랑입니다. 깜찍이스타일 찾아쥴래다가 인생 밑바닥...
# 977      51             6  (1, '_95_1214', '완벽한 메이크업이에요 너무 고마워요옹😖👍🏻'), (2...
# 1048     36             1                                                '0'
# 1251    236             1                                                '0'
# 1265      8             1                                                '0'
# 1366     34            10  (1, 'jo_kwanghee', '이쁘게 쓰세여~~~ 행보칸 밍이씨~~~'), (...
# 1541     35             2  (1, 'garamphotostudio', '우와....'), (2, 'cool30...
# 1720     78             1                                                '0'
# 2109     27             1                                                '0'
# 2110     27             1                                                '0'
# 2111     27             1                                                '0'
# 2112     27             1                                                '0'
# 2113     27             1                                                '0'
# 2114     27             1                                                '0'
# 2115     27             1                                                '0'
# 2116     27             1                                                '0'
# 2117     27             1                                                '0'
# 2118     27             1                                                '0'
# 2119     27             1                                                '0'
# 2120     27             1                                                '0'
# 2121     27             1                                                '0'
# 2122     27             1                                                '0'
# ...     ...           ...                                                ...
# 2148     27             1                                                '0'
# 2149     27             1                                                '0'
# 2150     27             1                                                '0'
# 2151     27             1                                                '0'
# 2152     27             1                                                '0'
# 2153     27             1                                                '0'
# 2154     27             1                                                '0'
# 2155     27             1                                                '0'
# 2156     27             1                                                '0'
# 2157     27             1                                                '0'
# 2158     27             1                                                '0'
# 2159     27             1                                                '0'
# 2160     27             1                                                '0'
# 2161     27             1                                                '0'
# 2162     27             1                                                '0'
# 2163     27             1                                                '0'
# 2164     27             1                                                '0'
# 2165     27             1                                                '0'
# 2166     27             1                                                '0'
# 2167     27             1                                                '0'
# 2168     27             1                                                '0'
# 2169     27             1                                                '0'
# 2170     27             1                                                '0'
# 2171     27             1                                                '0'
# 2172     27             1                                                '0'
# 2173     27             1                                                '0'
# 2174     27             1                                                '0'
# 2803     44             9  (1, 'avalabkorea', '사진이 너무 예쁘네요! 소통해요!'), (2, ...
# 2854      5             1                                                '0'
# 2979     54             1                                                '0'
#
#               datetime                                                img  \
# 65    2017-12-12 02:48  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 277   2017-12-08 14:06  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 388   2017-12-07 02:53  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 390   2017-12-07 01:29  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 508   2017-12-05 06:20  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 509   2017-12-05 05:16  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 651   2017-12-03 06:38  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 659   2017-12-03 05:10  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 660   2017-12-03 05:10  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 977   2017-11-28 07:24  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 1048  2017-11-27 07:14  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 1251  2017-11-25 00:45  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 1265  2017-11-24 14:49  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 1366  2017-11-23 13:13  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 1541  2017-11-21 11:17  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 1720  2017-11-18 18:19  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2109  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2110  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2111  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2112  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2113  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2114  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2115  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2116  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2117  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2118  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2119  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2120  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2121  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2122  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# ...                ...                                                ...
# 2148  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2149  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2150  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2151  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2152  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2153  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2154  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2155  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2156  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2157  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2158  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2159  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2160  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2161  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2162  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2163  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2164  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2165  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2166  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2167  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2168  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2169  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2170  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2171  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2172  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2173  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2174  2017-11-18 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2803  2017-11-14 15:32  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2854  2017-11-13 14:03  https://scontent-icn1-1.cdninstagram.com/t51.2...
# 2979  2017-11-11 04:31  https://scontent-icn1-1.cdninstagram.com/t51.2...
#
#                                                    tags         day
# 65    '#할리스', '#고구마라떼🍠', '#먹스타그램🍴', '#아리따움', '#프레시파워...  2017-12-12
# 277   '#추운', '#겨울', '#따뜻한', '#카페', '#에서', '#수다떨기', '...  2017-12-08
# 388   '#화장품아무도', '#안물안궁', '#마스카라', '#랑콤버츄어스', '#블러셔'...  2017-12-07
# 390   '#여자라면누구나', '#화장품', '#립스틱', '#립글로즈', '#아리따움', ...  2017-12-07
# 508   '#아리따움', '#할인', '#행사', '#아리따움', '#컬러라이브틴트', '#...  2017-12-05
# 509   '#광주', '#흔녀', '#selfie', '#selca', '#daily', '...  2017-12-05
# 651   '#독서⠀⠀⠀⠀⠀⠀⠀누군가의', '#인천', '#알라딘', '#중고서점', '#책'...  2017-12-03
# 659   '#motd', '#urbandecay', '#midnightcowbow', '#y...  2017-12-03
# 660   '#motd', '#urbandecay', '#midnightcowbow', '#y...  2017-12-03
# 977   '#입생로랑', '#올아워파운데이션', '#아리따움', '#리얼앰플브라이트너', '...  2017-11-28
# 1048  '#바비브라운', '#인텐시브스킨세럼파운데이션', '#코렉터컨실러', '#라이트피치...  2017-11-27
# 1251  '#이벤트⠀⠀⠀⠀⠀⠀⠀TWO호우와', '#상담문의', '#문의', '#저축문의', ...  2017-11-25
# 1265  '#다정메컵🍒', '#오늘의화장오늘은', '#바비브라운', '#토스트', '#엑셀'...  2017-11-24
# 1366  '#일상스타그램', '#코덕', '#쉐도우', '#틴트스트레스받을땐', '#돈쓰는게...  2017-11-23
# 1541  '#립', '#립스틱', '#틴트', '#입생로랑', '#로하셀', '#아리따움',...  2017-11-21
# 1720  '#171118', '#카노티디', '#오늘의화장', '#오늘의메이크업', '#mo...  2017-11-18
# 2109  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2110  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2111  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2112  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2113  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2114  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2115  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2116  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2117  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2118  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2119  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2120  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2121  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2122  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# ...                                                 ...         ...
# 2148  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2149  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2150  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2151  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2152  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2153  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2154  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2155  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2156  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2157  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2158  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2159  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2160  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2161  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2162  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2163  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2164  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2165  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2166  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2167  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2168  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2169  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2170  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2171  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2172  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2173  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2174  '#어퓨', '#페리페라', '#토니모리', '#맥', '#아리따움', '#미샤',...  2017-11-18
# 2803  '#아벤느', '#avene', '#입생로랑', '#입생로랑에센스', '#기초화장품...  2017-11-14
# 2854  '#가지고있는_립제품_발색', '#입생로랑틴트', '#입생로랑립스틱', '#페리페라...  2017-11-13
# 2979  '#에스티로더', '#아리따움', '#베네피트', '#데일리', '#샤넬', '#어...  2017-11-11
#
# [85 rows x 9 columns]

# %%
def insta_trends_word(datas, word):
    datas['day'] = [date[:10] for date in datas['datetime']]    # #월/일 값만 추가  2017-11-25형태
    check = [word in str(tags) for tags in datas.tags]

    trends = pd.DataFrame()
    trends['article'] = datas[check].groupby(datas['day'])['article'].count()  #  일자별 인스타 포스팅수
    trends['replies'] = datas[check].groupby(datas['day'])['replys_count'].sum() # 일자별 댓글 작성수
    trends['likes'] = datas[check].groupby(datas['day'])['likes'].sum()     # 일자별 좋아요 수
    trends['sum'] = trends.replies + trends.article + trends.likes
    
    return trends

# %%
WORD = '#잭버건디'
word_trends = insta_trends_word(datas, WORD)
word_trends.plot(y = ['article','replies','likes','sum'], title = '{} 트랜드'.format(WORD), figsize=(5,3))
word_trends.plot(y = ['article','replies'], title = '{} 트랜드'.format(WORD),figsize=(5,3))
